# %%
import pandas as pd
import numpy as np

# %%
safety = pd.read_csv('../data/safety_car_es.csv')

# %%
pd.set_option('display.max_columns', 40)

safety.head()
# Out:
#    circuitId circuitRef                    circuit_name  location country
# 0          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
# 1          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 2          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 4          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
#
#      lat      lng  alt  raceId  year  round          grand_prix        date
# 0  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22  \
# 1  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 2  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 3  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 4  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
#
# ...

# %%
safety = safety[safety['year'] == 2022]

safety.shape
# Out:
# (1230, 37)

# %%
safety['raceId'] = 1105
safety['year'] = 2023
safety['round'] = 8
safety['date'] = '2023-06-04'
safety['time'] = '13:00:00'

# %%
safety['raceId'].value_counts()
# Out:
# raceId
# 1105    1230
# Name: count, dtype: int64

# %%
safety['year'].value_counts()
# Out:
# year
# 2023    1230
# Name: count, dtype: int64

# %%
safety['round'].value_counts()
# Out:
# round
# 8    1230
# Name: count, dtype: int64

# %%
safety['date'].value_counts()
# Out:
# date
# 2023-06-04    1230
# Name: count, dtype: int64

# %%
safety['time'].value_counts()
# Out:
# time
# 13:00:00    1230
# Name: count, dtype: int64

# %%
safety.head()
# Out:
#    circuitId circuitRef                    circuit_name  location country
# 0          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
# 1          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 2          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 4          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
#
#      lat      lng  alt  raceId  year  round          grand_prix        date
# 0  41.57  2.26111  109    1105  2023      8  Spanish Grand Prix  2023-06-04  \
# 1  41.57  2.26111  109    1105  2023      8  Spanish Grand Prix  2023-06-04
# 2  41.57  2.26111  109    1105  2023      8  Spanish Grand Prix  2023-06-04
# 3  41.57  2.26111  109    1105  2023      8  Spanish Grand Prix  2023-06-04
# 4  41.57  2.26111  109    1105  2023      8  Spanish Grand Prix  2023-06-04
#
# ...

# %%
safety.forename.value_counts()
# Out:
# forename
# Lewis        66
# Max          66
# Carlos       66
# George       66
# Sergio       66
# Valtteri     66
# Esteban      66
# Lando        66
# Sebastian    65
# Pierre       65
# Fernando     65
# Lance        65
# Yuki         65
# Mick         65
# Daniel       65
# Kevin        64
# Alexander    64
# Nicholas     64
# Guanyu       28
# Charles      27
# Name: count, dtype: int64
