# %%
import pandas as pd
import numpy as np

# %%
data93 = [
    [1, 'Alain Prost', 'FRA', 'WILLIAMS RENAULT', 24],
    [2, 'Ayrton Senna', 'BRA', 'MCLAREN FORD', 26],
    [3, 'Damon Hill', 'GBR', 'WILLIAMS RENAULT', 12],
    [4, 'Michael Schumacher', 'GER', 'BENETTON FORD', 10],
    [5, 'Riccardo Patrese', 'ITA', 'BENETTON FORD', 2],
    [6, 'Jean Alesi', 'FRA', 'FERRARI', 0],
    [7, 'Martin Brundle', 'GBR', 'LIGIER RENAULT', 4],
    [8, 'Gerhard Berger', 'AUT', 'FERRARI', 1],
    [9, 'Johnny Herbert', 'GBR', 'LOTUS FORD', 6],
    [10, 'Mark Blundell', 'GBR', 'LIGIER RENAULT', 6],
    [11, 'Michael Andretti', 'USA', 'MCLAREN FORD', 0],
    [12, 'Karl Wendlinger', 'AUT', 'SAUBER', 0],
    [13, 'Christian Fittipaldi', 'BRA', 'MINARDI FORD', 3],
    [13, 'Jyrki Jarvilehto', 'FIN', 'SAUBER', 5],
    [15, 'Mika Hakkinen', 'FIN', 'MCLAREN FORD', 0],
    [16, 'Derek Warwick', 'GBR', 'FOOTWORK MUGEN HONDA', 0],
    [17, 'Philippe Alliot', 'FRA', 'LARROUSSE LAMBORGHINI', 2],
    [17, 'Rubens Barrichello', 'BRA', 'JORDAN HART', 0],
    [19, 'Fabrizio Barbazza', 'ITA', 'MINARDI FORD', 2],
    [20, 'Alessandro Zanardi', 'ITA', 'LOTUS FORD', 1],
    [20, 'Erik Comas', 'FRA', 'LARROUSSE LAMBORGHINI', 0],
    [20, 'Eddie Irvine', 'GBR', 'JORDAN HART', 0]
]

df93 = pd.DataFrame(data93, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])
df93['Year'] = '1993'
df93['Points'] = df93['Points'].astype(float)
df93 = df93.drop('Pos', axis=1)
df93= df93.sort_values(by='Points', ascending=False)
df93 = df93.reset_index(drop=True)

df93
# Out:
#                   Driver Nationality                   Team  Points  Year
# 0           Ayrton Senna         BRA           MCLAREN FORD    26.0  1993
# 1            Alain Prost         FRA       WILLIAMS RENAULT    24.0  1993
# 2             Damon Hill         GBR       WILLIAMS RENAULT    12.0  1993
# 3     Michael Schumacher         GER          BENETTON FORD    10.0  1993
# 4         Johnny Herbert         GBR             LOTUS FORD     6.0  1993
# 5          Mark Blundell         GBR         LIGIER RENAULT     6.0  1993
# 6       Jyrki Jarvilehto         FIN                 SAUBER     5.0  1993
# 7         Martin Brundle         GBR         LIGIER RENAULT     4.0  1993
# 8   Christian Fittipaldi         BRA           MINARDI FORD     3.0  1993
# 9        Philippe Alliot         FRA  LARROUSSE LAMBORGHINI     2.0  1993
# 10      Riccardo Patrese         ITA          BENETTON FORD     2.0  1993
# 11     Fabrizio Barbazza         ITA           MINARDI FORD     2.0  1993
# ...

# %%
data94 = [
    [1, 'Michael Schumacher', 'GER', 'BENETTON FORD', 40],
    [2, 'Damon Hill', 'GBR', 'WILLIAMS RENAULT', 7],
    [3, 'Gerhard Berger', 'AUT', 'FERRARI', 10],
    [4, 'Mika Hakkinen', 'FIN', 'MCLAREN PEUGEOT', 4],
    [5, 'Jean Alesi', 'FRA', 'FERRARI', 6],
    [6, 'Rubens Barrichello', 'BRA', 'JORDAN HART', 7],
    [7, 'Martin Brundle', 'GBR', 'MCLAREN PEUGEOT', 6],
    [8, 'David Coulthard', 'GBR', 'WILLIAMS RENAULT', 0],
    [9, 'Nigel Mansell', 'GBR', 'WILLIAMS RENAULT', 0],
    [10, 'Jos Verstappen', 'NED', 'BENETTON FORD', 0],
    [11, 'Olivier Panis', 'FRA', 'LIGIER RENAULT', 0],
    [12, 'Mark Blundell', 'GBR', 'TYRRELL YAMAHA', 0],
    [13, 'Heinz-Harald Frentzen', 'GER', 'SAUBER MERCEDES', 2],
    [14, 'Nicola Larini', 'ITA', 'FERRARI', 0],
    [15, 'Christian Fittipaldi', 'BRA', 'FOOTWORK FORD', 3],
    [16, 'Eddie Irvine', 'GBR', 'JORDAN HART', 0],
    [17, 'Ukyo Katayama', 'JPN', 'TYRRELL YAMAHA', 4],
    [18, 'Eric Bernard', 'FRA', 'LOTUS MUGEN HONDA', 0],
    [19, 'Karl Wendlinger', 'AUT', 'SAUBER MERCEDES', 0],
    [20, 'Andrea de Cesaris', 'ITA', 'SAUBER MERCEDES', 0],
    [21, 'Pierluigi Martini', 'ITA', 'MINARDI FORD', 0],
    [22, 'Gianni Morbidelli', 'ITA', 'FOOTWORK FORD', 0],
    [23, 'Erik Comas', 'FRA', 'LARROUSSE FORD', 1],
    [24, 'Michele Alboreto', 'ITA', 'MINARDI FORD', 1],
    [25, 'Jyrki Jarvilehto', 'FIN', 'SAUBER MERCEDES', 0]
]

df94 = pd.DataFrame(data94, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])
df94['Year'] = '1994'
df94['Points'] = df94['Points'].astype(float)
df94 = df94.drop('Pos', axis=1)
df94 = df94.sort_values(by='Points', ascending=False)
df94 = df94.reset_index(drop=True)

df94
# Out:
#                    Driver Nationality               Team  Points  Year
# 0      Michael Schumacher         GER      BENETTON FORD    40.0  1994
# 1          Gerhard Berger         AUT            FERRARI    10.0  1994
# 2              Damon Hill         GBR   WILLIAMS RENAULT     7.0  1994
# 3      Rubens Barrichello         BRA        JORDAN HART     7.0  1994
# 4              Jean Alesi         FRA            FERRARI     6.0  1994
# 5          Martin Brundle         GBR    MCLAREN PEUGEOT     6.0  1994
# 6           Mika Hakkinen         FIN    MCLAREN PEUGEOT     4.0  1994
# 7           Ukyo Katayama         JPN     TYRRELL YAMAHA     4.0  1994
# 8    Christian Fittipaldi         BRA      FOOTWORK FORD     3.0  1994
# 9   Heinz-Harald Frentzen         GER    SAUBER MERCEDES     2.0  1994
# 10             Erik Comas         FRA     LARROUSSE FORD     1.0  1994
# 11       Michele Alboreto         ITA       MINARDI FORD     1.0  1994
# ...

# %%
data95 = [
    [1, 'Michael Schumacher', 'GER', 'BENETTON RENAULT', 14],
    [2, 'Damon Hill', 'GBR', 'WILLIAMS RENAULT', 20],
    [3, 'David Coulthard', 'GBR', 'WILLIAMS RENAULT', 9],
    [4, 'Johnny Herbert', 'GBR', 'BENETTON RENAULT', 3],
    [5, 'Jean Alesi', 'FRA', 'FERRARI', 14],
    [6, 'Gerhard Berger', 'AUT', 'FERRARI', 9],
    [7, 'Mika Hakkinen', 'FIN', 'MCLAREN MERCEDES', 5],
    [8, 'Olivier Panis', 'FRA', 'LIGIER MUGEN HONDA', 0],
    [9, 'Heinz-Harald Frentzen', 'GER', 'SAUBER FORD', 3],
    [10, 'Mark Blundell', 'GBR', 'MCLAREN MERCEDES', 1],
    [11, 'Rubens Barrichello', 'BRA', 'JORDAN PEUGEOT', 0],
    [12, 'Eddie Irvine', 'GBR', 'JORDAN PEUGEOT', 0],
    [13, 'Martin Brundle', 'GBR', 'LIGIER MUGEN HONDA', 0],
    [14, 'Gianni Morbidelli', 'ITA', 'FOOTWORK HART', 0],
    [15, 'Mika Salo', 'FIN', 'TYRRELL YAMAHA', 0],
    [16, 'Jean-Christophe Boullion', 'FRA', 'SAUBER FORD', 0],
    [17, 'Aguri Suzuki', 'JPN', 'LIGIER MUGEN HONDA', 0],
    [18, 'Pedro Lamy', 'POR', 'MINARDI FORD', 0]
]

df95 = pd.DataFrame(data95, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])
df95['Year'] = '1995'
df95['Points'] = df95['Points'].astype(float)
df95 = df95.drop('Pos', axis=1)
df95 = df95.sort_values(by='Points', ascending=False)
df95 = df95.reset_index(drop=True)

df95
# Out:
#                       Driver Nationality                Team  Points  Year
# 0                 Damon Hill         GBR    WILLIAMS RENAULT    20.0  1995
# 1         Michael Schumacher         GER    BENETTON RENAULT    14.0  1995
# 2                 Jean Alesi         FRA             FERRARI    14.0  1995
# 3            David Coulthard         GBR    WILLIAMS RENAULT     9.0  1995
# 4             Gerhard Berger         AUT             FERRARI     9.0  1995
# 5              Mika Hakkinen         FIN    MCLAREN MERCEDES     5.0  1995
# 6      Heinz-Harald Frentzen         GER         SAUBER FORD     3.0  1995
# 7             Johnny Herbert         GBR    BENETTON RENAULT     3.0  1995
# 8              Mark Blundell         GBR    MCLAREN MERCEDES     1.0  1995
# 9              Olivier Panis         FRA  LIGIER MUGEN HONDA     0.0  1995
# 10        Rubens Barrichello         BRA      JORDAN PEUGEOT     0.0  1995
# ...

# %%
data96 = [
    [1, 'Damon Hill', 'GBR', 'WILLIAMS RENAULT', 43],
    [2, 'Jacques Villeneuve', 'CAN', 'WILLIAMS RENAULT', 22],
    [3, 'Michael Schumacher', 'GER', 'FERRARI', 16],
    [4, 'Jean Alesi', 'FRA', 'BENETTON RENAULT', 11],
    [5, 'Mika Hakkinen', 'FIN', 'MCLAREN MERCEDES', 6],
    [6, 'Gerhard Berger', 'AUT', 'BENETTON RENAULT', 7],
    [7, 'David Coulthard', 'GBR', 'MCLAREN MERCEDES', 10],
    [8, 'Rubens Barrichello', 'BRA', 'JORDAN PEUGEOT', 7],
    [9, 'Olivier Panis', 'FRA', 'LIGIER MUGEN HONDA', 11],
    [10, 'Eddie Irvine', 'GBR', 'FERRARI', 10],
    [11, 'Martin Brundle', 'GBR', 'JORDAN PEUGEOT', 1],
    [12, 'Heinz-Harald Frentzen', 'GER', 'SAUBER FORD', 3],
    [13, 'Mika Salo', 'FIN', 'TYRRELL YAMAHA', 5],
    [14, 'Johnny Herbert', 'GBR', 'SAUBER FORD', 4],
    [15, 'Pedro Diniz', 'BRA', 'LIGIER MUGEN HONDA', 0],
    [16, 'Jos Verstappen', 'NED', 'FOOTWORK HART', 1]
]

df96 = pd.DataFrame(data96, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])
df96['Year'] = '1996'
df96['Points'] = df96['Points'].astype(float)
df96 = df96.drop('Pos', axis=1)
df96 = df96.sort_values(by='Points', ascending=False)
df96 = df96.reset_index(drop=True)

df96
# Out:
#                    Driver Nationality                Team  Points  Year
# 0              Damon Hill         GBR    WILLIAMS RENAULT    43.0  1996
# 1      Jacques Villeneuve         CAN    WILLIAMS RENAULT    22.0  1996
# 2      Michael Schumacher         GER             FERRARI    16.0  1996
# 3              Jean Alesi         FRA    BENETTON RENAULT    11.0  1996
# 4           Olivier Panis         FRA  LIGIER MUGEN HONDA    11.0  1996
# 5         David Coulthard         GBR    MCLAREN MERCEDES    10.0  1996
# 6            Eddie Irvine         GBR             FERRARI    10.0  1996
# 7          Gerhard Berger         AUT    BENETTON RENAULT     7.0  1996
# 8      Rubens Barrichello         BRA      JORDAN PEUGEOT     7.0  1996
# 9           Mika Hakkinen         FIN    MCLAREN MERCEDES     6.0  1996
# 10              Mika Salo         FIN      TYRRELL YAMAHA     5.0  1996
# 11         Johnny Herbert         GBR         SAUBER FORD     4.0  1996
# ...

# %%
data97 = [
    [1, 'Jacques Villeneuve', 'CAN', 'WILLIAMS RENAULT', 20],
    ['DQ', 'Michael Schumacher', 'GER', 'FERRARI', 24],
    [2, 'Heinz-Harald Frentzen', 'GER', 'WILLIAMS RENAULT', 10],
    [3, 'David Coulthard', 'GBR', 'MCLAREN MERCEDES', 10],
    [4, 'Jean Alesi', 'FRA', 'BENETTON RENAULT', 3],
    [5, 'Gerhard Berger', 'AUT', 'BENETTON RENAULT', 10],
    [6, 'Mika Hakkinen', 'FIN', 'MCLAREN MERCEDES', 10],
    [7, 'Eddie Irvine', 'GBR', 'FERRARI', 14],
    [8, 'Giancarlo Fisichella', 'ITA', 'JORDAN PEUGEOT', 4],
    [9, 'Olivier Panis', 'FRA', 'PROST MUGEN HONDA', 9],
    [10, 'Johnny Herbert', 'GBR', 'SAUBER PETRONAS', 3],
    [11, 'Ralf Schumacher', 'GER', 'JORDAN PEUGEOT', 4],
    [12, 'Damon Hill', 'GBR', 'ARROWS YAMAHA', 0],
    [13, 'Rubens Barrichello', 'BRA', 'STEWART FORD', 6],
    [14, 'Alexander Wurz', 'AUT', 'BENETTON RENAULT', 0],
    [15, 'Jarno Trulli', 'ITA', 'PROST MUGEN HONDA', 0],
    [16, 'Mika Salo', 'FIN', 'TYRRELL FORD', 2],
    [17, 'Pedro Diniz', 'BRA', 'ARROWS YAMAHA', 0],
    [18, 'Shinji Nakano', 'JPN', 'PROST MUGEN HONDA', 0],
    [19, 'Nicola Larini', 'ITA', 'SAUBER PETRONAS', 0]
]

df97 = pd.DataFrame(data97, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])
df97['Year'] = '1997'
df97['Points'] = df97['Points'].astype(float)
df97 = df97.drop('Pos', axis=1)
df97 = df97.sort_values(by='Points', ascending=False)
df97 = df97.reset_index(drop=True)

df97
# Out:
#                    Driver Nationality               Team  Points  Year
# 0      Michael Schumacher         GER            FERRARI    24.0  1997
# 1      Jacques Villeneuve         CAN   WILLIAMS RENAULT    20.0  1997
# 2            Eddie Irvine         GBR            FERRARI    14.0  1997
# 3   Heinz-Harald Frentzen         GER   WILLIAMS RENAULT    10.0  1997
# 4         David Coulthard         GBR   MCLAREN MERCEDES    10.0  1997
# 5          Gerhard Berger         AUT   BENETTON RENAULT    10.0  1997
# 6           Mika Hakkinen         FIN   MCLAREN MERCEDES    10.0  1997
# 7           Olivier Panis         FRA  PROST MUGEN HONDA     9.0  1997
# 8      Rubens Barrichello         BRA       STEWART FORD     6.0  1997
# 9         Ralf Schumacher         GER     JORDAN PEUGEOT     4.0  1997
# 10   Giancarlo Fisichella         ITA     JORDAN PEUGEOT     4.0  1997
# 11         Johnny Herbert         GBR    SAUBER PETRONAS     3.0  1997
# ...

# %%
data98 = [
    [1, 'Mika Hakkinen', 'FIN', 'MCLAREN MERCEDES', 26],
    [2, 'Michael Schumacher', 'GER', 'FERRARI', 20],
    [3, 'David Coulthard', 'GBR', 'MCLAREN MERCEDES', 23],
    [4, 'Eddie Irvine', 'GBR', 'FERRARI', 11],
    [5, 'Jacques Villeneuve', 'CAN', 'WILLIAMS MECACHROME', 5],
    [6, 'Damon Hill', 'GBR', 'JORDAN MUGEN HONDA', 0],
    [7, 'Heinz-Harald Frentzen', 'GER', 'WILLIAMS MECACHROME', 8],
    [8, 'Alexander Wurz', 'AUT', 'BENETTON PLAYLIFE', 6],
    [9, 'Giancarlo Fisichella', 'ITA', 'BENETTON PLAYLIFE', 1],
    [10, 'Ralf Schumacher', 'GER', 'JORDAN MUGEN HONDA', 0],
    [11, 'Jean Alesi', 'FRA', 'SAUBER PETRONAS', 3],
    [12, 'Rubens Barrichello', 'BRA', 'STEWART FORD', 0],
    [13, 'Mika Salo', 'FIN', 'ARROWS', 0],
    [14, 'Pedro Diniz', 'BRA', 'ARROWS', 0],
    [15, 'Johnny Herbert', 'GBR', 'SAUBER PETRONAS', 1],
    [16, 'Jan Magnussen', 'DEN', 'STEWART FORD', 0],
    [17, 'Jarno Trulli', 'ITA', 'PROST PEUGEOT', 0],
    [18, 'Ricardo Rosset', 'BRA', 'TYRRELL FORD', 0],
    [19, 'Olivier Panis', 'FRA', 'PROST PEUGEOT', 0],
    [20, 'Toranosuke Takagi', 'JPN', 'TYRRELL FORD', 0],
    [21, 'Shinji Nakano', 'JPN', 'MINARDI FORD', 0],
    [22, 'Esteban Tuero', 'ARG', 'MINARDI FORD', 0],
    [23, 'Jos Verstappen', 'NED', 'STEWART FORD', 0]
]

df98 = pd.DataFrame(data98, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])

df98['Year'] = '1998'
df98['Points'] = df98['Points'].astype(float)
df98 = df98.drop('Pos', axis=1)
df98 = df98.sort_values(by='Points', ascending=False)
df98 = df98.reset_index(drop=True)

df98
# Out:
#                    Driver Nationality                 Team  Points  Year
# 0           Mika Hakkinen         FIN     MCLAREN MERCEDES    26.0  1998
# 1         David Coulthard         GBR     MCLAREN MERCEDES    23.0  1998
# 2      Michael Schumacher         GER              FERRARI    20.0  1998
# 3            Eddie Irvine         GBR              FERRARI    11.0  1998
# 4   Heinz-Harald Frentzen         GER  WILLIAMS MECACHROME     8.0  1998
# 5          Alexander Wurz         AUT    BENETTON PLAYLIFE     6.0  1998
# 6      Jacques Villeneuve         CAN  WILLIAMS MECACHROME     5.0  1998
# 7              Jean Alesi         FRA      SAUBER PETRONAS     3.0  1998
# 8    Giancarlo Fisichella         ITA    BENETTON PLAYLIFE     1.0  1998
# 9          Johnny Herbert         GBR      SAUBER PETRONAS     1.0  1998
# 10           Jarno Trulli         ITA        PROST PEUGEOT     0.0  1998
# 11          Esteban Tuero         ARG         MINARDI FORD     0.0  1998
# ...

# %%
data99 = [
    [1, 'Mika Hakkinen', 'FIN', 'MCLAREN MERCEDES', 14],
    [2, 'Eddie Irvine', 'GBR', 'FERRARI', 18],
    [3, 'Heinz-Harald Frentzen', 'GER', 'JORDAN MUGEN HONDA', 13],
    [4, 'David Coulthard', 'GBR', 'MCLAREN MERCEDES', 6],
    [5, 'Michael Schumacher', 'GER', 'FERRARI', 26],
    [6, 'Ralf Schumacher', 'GER', 'WILLIAMS SUPERTEC', 7],
    [7, 'Rubens Barrichello', 'BRA', 'STEWART FORD', 6],
    [8, 'Johnny Herbert', 'GBR', 'STEWART FORD', 0],
    [9, 'Giancarlo Fisichella', 'ITA', 'BENETTON PLAYLIFE', 7],
    [10, 'Mika Salo', 'FIN', 'FERRARI', 0],
    [11, 'Jarno Trulli', 'ITA', 'PROST PEUGEOT', 0],
    [12, 'Damon Hill', 'GBR', 'JORDAN MUGEN HONDA', 3],
    [13, 'Alexander Wurz', 'AUT', 'BENETTON PLAYLIFE', 1],
    [14, 'Pedro Diniz', 'BRA', 'SAUBER PETRONAS', 0],
    [15, 'Olivier Panis', 'FRA', 'PROST PEUGEOT', 1],
    [16, 'Jean Alesi', 'FRA', 'SAUBER PETRONAS', 1],
    [17, 'Pedro de la Rosa', 'ESP', 'ARROWS', 1],
    [18, 'Marc Gene', 'ESP', 'MINARDI FORD', 0]
]

df99 = pd.DataFrame(data99, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])

df99['Year'] = '1999'
df99['Points'] = df99['Points'].astype(float)
df99 = df99.drop('Pos', axis=1)
df99 = df99.sort_values(by='Points', ascending=False)
df99 = df99.reset_index(drop=True)

df99
# Out:
#                    Driver Nationality                Team  Points  Year
# 0      Michael Schumacher         GER             FERRARI    26.0  1999
# 1            Eddie Irvine         GBR             FERRARI    18.0  1999
# 2           Mika Hakkinen         FIN    MCLAREN MERCEDES    14.0  1999
# 3   Heinz-Harald Frentzen         GER  JORDAN MUGEN HONDA    13.0  1999
# 4         Ralf Schumacher         GER   WILLIAMS SUPERTEC     7.0  1999
# 5    Giancarlo Fisichella         ITA   BENETTON PLAYLIFE     7.0  1999
# 6         David Coulthard         GBR    MCLAREN MERCEDES     6.0  1999
# 7      Rubens Barrichello         BRA        STEWART FORD     6.0  1999
# 8              Damon Hill         GBR  JORDAN MUGEN HONDA     3.0  1999
# 9           Olivier Panis         FRA       PROST PEUGEOT     1.0  1999
# 10       Pedro de la Rosa         ESP              ARROWS     1.0  1999
# 11             Jean Alesi         FRA     SAUBER PETRONAS     1.0  1999
# ...

# %%
data00 = [
    [1, 'Michael Schumacher', 'GER', 'FERRARI', 34],
    [2, 'Mika Hakkinen', 'FIN', 'MCLAREN MERCEDES', 12],
    [3, 'David Coulthard', 'GBR', 'MCLAREN MERCEDES', 14],
    [4, 'Rubens Barrichello', 'BRA', 'FERRARI', 9],
    [5, 'Ralf Schumacher', 'GER', 'WILLIAMS BMW', 9],
    [6, 'Giancarlo Fisichella', 'ITA', 'BENETTON PLAYLIFE', 8],
    [7, 'Jacques Villeneuve', 'CAN', 'BAR HONDA', 5],
    [8, 'Jenson Button', 'GBR', 'WILLIAMS BMW', 3],
    [9, 'Heinz-Harald Frentzen', 'GER', 'JORDAN MUGEN HONDA', 4],
    [10, 'Jarno Trulli', 'ITA', 'JORDAN MUGEN HONDA', 4],
    [11, 'Mika Salo', 'FIN', 'SAUBER PETRONAS', 1],
    [12, 'Jos Verstappen', 'NED', 'ARROWS SUPERTEC', 0],
    [13, 'Eddie Irvine', 'GBR', 'JAGUAR COSWORTH', 0],
    [14, 'Ricardo Zonta', 'BRA', 'BAR HONDA', 1],
    [15, 'Alexander Wurz', 'AUT', 'BENETTON PLAYLIFE', 0],
    [16, 'Pedro de la Rosa', 'ESP', 'ARROWS SUPERTEC', 0],
    [17, 'Pedro Diniz', 'BRA', 'SAUBER PETRONAS', 0],
    [18, 'Johnny Herbert', 'GBR', 'JAGUAR COSWORTH', 0],
    [19, 'Marc Gene', 'ESP', 'MINARDI FONDMETAL', 0],
    [20, 'Gaston Mazzacane', 'ARG', 'MINARDI FONDMETAL', 0],
    [21, 'Nick Heidfeld', 'GER', 'PROST PEUGEOT', 0],
    [22, 'Jean Alesi', 'FRA', 'PROST PEUGEOT', 0],
    [23, 'Luciano Burti', 'BRA', 'JAGUAR COSWORTH', 0]
]

df00 = pd.DataFrame(data00, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])

df00['Year'] = '2000'
df00['Points'] = df00['Points'].astype(float)
df00 = df00.drop('Pos', axis=1)
df00 = df00.sort_values(by='Points', ascending=False)
df00 = df00.reset_index(drop=True)

df00
# Out:
#                    Driver Nationality                Team  Points  Year
# 0      Michael Schumacher         GER             FERRARI    34.0  2000
# 1         David Coulthard         GBR    MCLAREN MERCEDES    14.0  2000
# 2           Mika Hakkinen         FIN    MCLAREN MERCEDES    12.0  2000
# 3      Rubens Barrichello         BRA             FERRARI     9.0  2000
# 4         Ralf Schumacher         GER        WILLIAMS BMW     9.0  2000
# 5    Giancarlo Fisichella         ITA   BENETTON PLAYLIFE     8.0  2000
# 6      Jacques Villeneuve         CAN           BAR HONDA     5.0  2000
# 7            Jarno Trulli         ITA  JORDAN MUGEN HONDA     4.0  2000
# 8   Heinz-Harald Frentzen         GER  JORDAN MUGEN HONDA     4.0  2000
# 9           Jenson Button         GBR        WILLIAMS BMW     3.0  2000
# 10              Mika Salo         FIN     SAUBER PETRONAS     1.0  2000
# 11          Ricardo Zonta         BRA           BAR HONDA     1.0  2000
# ...

# %%
data01 = [
    [1, 'Michael Schumacher', 'GER', 'FERRARI', 26],
    [2, 'David Coulthard', 'GBR', 'MCLAREN MERCEDES', 26],
    [3, 'Rubens Barrichello', 'BRA', 'FERRARI', 14],
    [4, 'Ralf Schumacher', 'GER', 'WILLIAMS BMW', 12],
    [5, 'Mika Hakkinen', 'FIN', 'MCLAREN MERCEDES', 4],
    [6, 'Juan Pablo Montoya', 'COL', 'WILLIAMS BMW', 0],
    [7, 'Jacques Villeneuve', 'CAN', 'BAR HONDA', 0],
    [8, 'Nick Heidfeld', 'GER', 'SAUBER PETRONAS', 7],
    [9, 'Jarno Trulli', 'ITA', 'JORDAN HONDA', 4],
    [10, 'Kimi Räikkönen', 'FIN', 'SAUBER PETRONAS', 1],
    [11, 'Giancarlo Fisichella', 'ITA', 'BENETTON RENAULT', 1],
    [12, 'Eddie Irvine', 'GBR', 'JAGUAR COSWORTH', 0],
    [13, 'Heinz-Harald Frentzen', 'GER', 'PROST ACER', 6],
    [14, 'Olivier Panis', 'FRA', 'BAR HONDA', 3],
    [15, 'Jean Alesi', 'FRA', 'JORDAN HONDA', 0],
    [16, 'Pedro de la Rosa', 'ESP', 'JAGUAR COSWORTH', 0],
    [17, 'Jenson Button', 'GBR', 'BENETTON RENAULT', 0],
    [18, 'Jos Verstappen', 'NED', 'ARROWS ASIATECH', 0]
]

df01 = pd.DataFrame(data01, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])

df01['Year'] = '2001'
df01['Points'] = df01['Points'].astype(float)
df01 = df01.drop('Pos', axis=1)
df01 = df01.sort_values(by='Points', ascending=False)
df01 = df01.reset_index(drop=True)

df01
# Out:
#                    Driver Nationality              Team  Points  Year
# 0      Michael Schumacher         GER           FERRARI    26.0  2001
# 1         David Coulthard         GBR  MCLAREN MERCEDES    26.0  2001
# 2      Rubens Barrichello         BRA           FERRARI    14.0  2001
# 3         Ralf Schumacher         GER      WILLIAMS BMW    12.0  2001
# 4           Nick Heidfeld         GER   SAUBER PETRONAS     7.0  2001
# 5   Heinz-Harald Frentzen         GER        PROST ACER     6.0  2001
# 6           Mika Hakkinen         FIN  MCLAREN MERCEDES     4.0  2001
# 7            Jarno Trulli         ITA      JORDAN HONDA     4.0  2001
# 8           Olivier Panis         FRA         BAR HONDA     3.0  2001
# 9    Giancarlo Fisichella         ITA  BENETTON RENAULT     1.0  2001
# 10         Kimi Räikkönen         FIN   SAUBER PETRONAS     1.0  2001
# 11           Eddie Irvine         GBR   JAGUAR COSWORTH     0.0  2001
# ...

# %%
data02 = [
    [1, 'Michael Schumacher', 'GER', 'FERRARI', 34],
    [2, 'Rubens Barrichello', 'BRA', 'FERRARI', 6],
    [3, 'Juan Pablo Montoya', 'COL', 'WILLIAMS BMW', 17],
    [4, 'Ralf Schumacher', 'GER', 'WILLIAMS BMW', 20],
    [5, 'David Coulthard', 'GBR', 'MCLAREN MERCEDES', 5],
    [6, 'Kimi Räikkönen', 'FIN', 'MCLAREN MERCEDES', 4],
    [7, 'Jenson Button', 'GBR', 'RENAULT', 8],
    [8, 'Jarno Trulli', 'ITA', 'RENAULT', 0],
    [9, 'Eddie Irvine', 'GBR', 'JAGUAR COSWORTH', 3],
    [10, 'Nick Heidfeld', 'GER', 'SAUBER PETRONAS', 2],
    [11, 'Giancarlo Fisichella', 'ITA', 'JORDAN HONDA', 0],
    [12, 'Jacques Villeneuve', 'CAN', 'BAR HONDA', 0],
    [13, 'Felipe Massa', 'BRA', 'SAUBER PETRONAS', 1],
    [14, 'Olivier Panis', 'FRA', 'BAR HONDA', 0],
    [15, 'Takuma Sato', 'JPN', 'JORDAN HONDA', 0],
    [16, 'Mark Webber', 'AUS', 'MINARDI ASIATECH', 2],
    [17, 'Mika Salo', 'FIN', 'TOYOTA', 2],
    [18, 'Heinz-Harald Frentzen', 'GER', 'SAUBER PETRONAS', 0],
    [19, 'Allan McNish', 'GBR', 'TOYOTA', 0],
    [20, 'Alex Yoong', 'MAS', 'MINARDI ASIATECH', 0],
    [21, 'Pedro de la Rosa', 'ESP', 'JAGUAR COSWORTH', 0],
    [22, 'Enrique Bernoldi', 'BRA', 'ARROWS COSWORTH', 0]
]

df02 = pd.DataFrame(data02, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])

df02['Year'] = '2002'
df02['Points'] = df02['Points'].astype(float)
df02 = df02.drop('Pos', axis=1)
df02 = df02.sort_values(by='Points', ascending=False)
df02 = df02.reset_index(drop=True)

df02
# Out:
#                    Driver Nationality              Team  Points  Year
# 0      Michael Schumacher         GER           FERRARI    34.0  2002
# 1         Ralf Schumacher         GER      WILLIAMS BMW    20.0  2002
# 2      Juan Pablo Montoya         COL      WILLIAMS BMW    17.0  2002
# 3           Jenson Button         GBR           RENAULT     8.0  2002
# 4      Rubens Barrichello         BRA           FERRARI     6.0  2002
# 5         David Coulthard         GBR  MCLAREN MERCEDES     5.0  2002
# 6          Kimi Räikkönen         FIN  MCLAREN MERCEDES     4.0  2002
# 7            Eddie Irvine         GBR   JAGUAR COSWORTH     3.0  2002
# 8               Mika Salo         FIN            TOYOTA     2.0  2002
# 9           Nick Heidfeld         GER   SAUBER PETRONAS     2.0  2002
# 10            Mark Webber         AUS  MINARDI ASIATECH     2.0  2002
# 11           Felipe Massa         BRA   SAUBER PETRONAS     1.0  2002
# ...

# %%
data03 = [
    [1, 'Michael Schumacher', 'GER', 'FERRARI', 18],
    [2, 'Kimi Räikkönen', 'FIN', 'MCLAREN MERCEDES', 32],
    [3, 'Juan Pablo Montoya', 'COL', 'WILLIAMS BMW', 10],
    [4, 'Rubens Barrichello', 'BRA', 'FERRARI', 14],
    [5, 'Ralf Schumacher', 'GER', 'WILLIAMS BMW', 13],
    [6, 'Fernando Alonso', 'ESP', 'RENAULT', 17],
    [7, 'David Coulthard', 'GBR', 'MCLAREN MERCEDES', 19],
    [8, 'Jarno Trulli', 'ITA', 'RENAULT', 9],
    [9, 'Jenson Button', 'GBR', 'BAR HONDA', 3],
    [10, 'Mark Webber', 'AUS', 'JAGUAR COSWORTH', 0],
    [11, 'Heinz-Harald Frentzen', 'GER', 'SAUBER PETRONAS', 7],
    [12, 'Giancarlo Fisichella', 'ITA', 'JORDAN FORD', 10],
    [13, 'Cristiano da Matta', 'BRA', 'TOYOTA', 0],
    [14, 'Nick Heidfeld', 'GER', 'SAUBER PETRONAS', 1],
    [15, 'Olivier Panis', 'FRA', 'TOYOTA', 0],
    [16, 'Jacques Villeneuve', 'CAN', 'BAR HONDA', 3],
    [17, 'Marc Gene', 'ESP', 'WILLIAMS BMW', 0],
    [18, 'Takuma Sato', 'JPN', 'BAR HONDA', 0],
    [19, 'Ralph Firman', 'IRL', 'JORDAN FORD', 0],
    [20, 'Justin Wilson', 'GBR', 'JAGUAR COSWORTH', 0],
    [21, 'Antonio Pizzonia', 'BRA', 'JAGUAR COSWORTH', 0],
    [22, 'Jos Verstappen', 'NED', 'MINARDI COSWORTH', 0],
    [23, 'Nicolas Kiesa', 'DEN', 'MINARDI COSWORTH', 0],
    [24, 'Zsolt Baumgartner', 'HUN', 'JORDAN FORD', 0]
]

df03 = pd.DataFrame(data03, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])

df03['Year'] = '2003'
df03['Points'] = df03['Points'].astype(float)
df03 = df03.drop('Pos', axis=1)
df03 = df03.sort_values(by='Points', ascending=False)
df03 = df03.reset_index(drop=True)

df03
# Out:
#                    Driver Nationality              Team  Points  Year
# 0          Kimi Räikkönen         FIN  MCLAREN MERCEDES    32.0  2003
# 1         David Coulthard         GBR  MCLAREN MERCEDES    19.0  2003
# 2      Michael Schumacher         GER           FERRARI    18.0  2003
# 3         Fernando Alonso         ESP           RENAULT    17.0  2003
# 4      Rubens Barrichello         BRA           FERRARI    14.0  2003
# 5         Ralf Schumacher         GER      WILLIAMS BMW    13.0  2003
# 6      Juan Pablo Montoya         COL      WILLIAMS BMW    10.0  2003
# 7    Giancarlo Fisichella         ITA       JORDAN FORD    10.0  2003
# 8            Jarno Trulli         ITA           RENAULT     9.0  2003
# 9   Heinz-Harald Frentzen         GER   SAUBER PETRONAS     7.0  2003
# 10     Jacques Villeneuve         CAN         BAR HONDA     3.0  2003
# 11          Jenson Button         GBR         BAR HONDA     3.0  2003
# ...

# %%
data04 = [
    [1, 'Michael Schumacher', 'GER', 'FERRARI', 40],
    [2, 'Rubens Barrichello', 'BRA', 'FERRARI', 24],
    [3, 'Jenson Button', 'GBR', 'BAR HONDA', 23],
    [4, 'Fernando Alonso', 'ESP', 'RENAULT', 16],
    [5, 'Juan Pablo Montoya', 'COL', 'WILLIAMS BMW', 18],
    [6, 'Jarno Trulli', 'ITA', 'TOYOTA', 15],
    [7, 'Kimi Räikkönen', 'FIN', 'MCLAREN MERCEDES', 1],
    [8, 'Takuma Sato', 'JPN', 'BAR HONDA', 4],
    [9, 'Ralf Schumacher', 'GER', 'WILLIAMS BMW', 9],
    [10, 'David Coulthard', 'GBR', 'MCLAREN MERCEDES', 4],
    [11, 'Giancarlo Fisichella', 'ITA', 'SAUBER PETRONAS', 0],
    [12, 'Felipe Massa', 'BRA', 'SAUBER PETRONAS', 1],
    [13, 'Mark Webber', 'AUS', 'JAGUAR COSWORTH', 1],
    [14, 'Olivier Panis', 'FRA', 'TOYOTA', 0],
    [15, 'Antonio Pizzonia', 'BRA', 'WILLIAMS BMW', 0],
    [16, 'Christian Klien', 'AUT', 'JAGUAR COSWORTH', 0],
    [17, 'Cristiano da Matta', 'BRA', 'TOYOTA', 0],
    [18, 'Nick Heidfeld', 'GER', 'JORDAN FORD', 0],
    [19, 'Timo Glock', 'GER', 'JORDAN FORD', 0],
    [20, 'Zsolt Baumgartner', 'HUN', 'MINARDI COSWORTH', 0],
    [21, 'Jacques Villeneuve', 'CAN', 'RENAULT', 0],
    [22, 'Ricardo Zonta', 'BRA', 'TOYOTA', 0],
    [23, 'Marc Gene', 'ESP', 'WILLIAMS BMW', 0],
    [24, 'Giorgio Pantano', 'ITA', 'JORDAN FORD', 0],
    [25, 'Gianmaria Bruni', 'ITA', 'MINARDI COSWORTH', 0]
]

df04 = pd.DataFrame(data04, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])

df04['Year'] = '2004'
df04['Points'] = df04['Points'].astype(float)
df04 = df04.drop('Pos', axis=1)
df04 = df04.sort_values(by='Points', ascending=False)
df04 = df04.reset_index(drop=True)

df04
# Out:
#                   Driver Nationality              Team  Points  Year
# 0     Michael Schumacher         GER           FERRARI    40.0  2004
# 1     Rubens Barrichello         BRA           FERRARI    24.0  2004
# 2          Jenson Button         GBR         BAR HONDA    23.0  2004
# 3     Juan Pablo Montoya         COL      WILLIAMS BMW    18.0  2004
# 4        Fernando Alonso         ESP           RENAULT    16.0  2004
# 5           Jarno Trulli         ITA            TOYOTA    15.0  2004
# 6        Ralf Schumacher         GER      WILLIAMS BMW     9.0  2004
# 7            Takuma Sato         JPN         BAR HONDA     4.0  2004
# 8        David Coulthard         GBR  MCLAREN MERCEDES     4.0  2004
# 9           Felipe Massa         BRA   SAUBER PETRONAS     1.0  2004
# 10           Mark Webber         AUS   JAGUAR COSWORTH     1.0  2004
# 11        Kimi Räikkönen         FIN  MCLAREN MERCEDES     1.0  2004
# 12  Giancarlo Fisichella         ITA   SAUBER PETRONAS     0.0  2004
# ...

# %%
data05 = [
    [1, 'Fernando Alonso', 'ESP', 'RENAULT', 36],
    [2, 'Kimi Räikkönen', 'FIN', 'MCLAREN MERCEDES', 7],
    [3, 'Michael Schumacher', 'GER', 'FERRARI', 10],
    [4, 'Juan Pablo Montoya', 'COL', 'MCLAREN MERCEDES', 8],
    [5, 'Giancarlo Fisichella', 'ITA', 'RENAULT', 10],
    [6, 'Ralf Schumacher', 'GER', 'TOYOTA', 9],
    [7, 'Jarno Trulli', 'ITA', 'TOYOTA', 20],
    [8, 'Rubens Barrichello', 'BRA', 'FERRARI', 8],
    [9, 'Jenson Button', 'GBR', 'BAR HONDA', 0],
    [10, 'Mark Webber', 'AUS', 'WILLIAMS BMW', 9],
    [11, 'Nick Heidfeld', 'GER', 'WILLIAMS BMW', 9],
    [12, 'David Coulthard', 'GBR', 'RBR COSWORTH', 9],
    [13, 'Felipe Massa', 'BRA', 'SAUBER PETRONAS', 2],
    [14, 'Jacques Villeneuve', 'CAN', 'SAUBER PETRONAS', 5],
    [15, 'Christian Klien', 'AUT', 'RBR COSWORTH', 3],
    [16, 'Tiago Monteiro', 'POR', 'JORDAN TOYOTA', 0],
    [17, 'Alexander Wurz', 'AUT', 'MCLAREN MERCEDES', 6],
    [18, 'Narain Karthikeyan', 'IND', 'JORDAN TOYOTA', 0],
    [19, 'Christijan Albers', 'NED', 'MINARDI COSWORTH', 0],
    [20, 'Pedro de la Rosa', 'ESP', 'MCLAREN MERCEDES', 4],
    [21, 'Patrick Friesacher', 'AUT', 'MINARDI COSWORTH', 0],
    [22, 'Antonio Pizzonia', 'BRA', 'WILLIAMS BMW', 0],
    [23, 'Takuma Sato', 'JPN', 'BAR HONDA', 0],
    [24, 'Vitantonio Liuzzi', 'ITA', 'RBR COSWORTH', 1],
    [25, 'Robert Doornbos', 'MON', 'MINARDI COSWORTH', 0]
]

df05 = pd.DataFrame(data05, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])

df05['Year'] = '2005'
df05['Points'] = df05['Points'].astype(float)
df05 = df05.drop('Pos', axis=1)
df05 = df05.sort_values(by='Points', ascending=False)
df05 = df05.reset_index(drop=True)

df05
# Out:
#                   Driver Nationality              Team  Points  Year
# 0        Fernando Alonso         ESP           RENAULT    36.0  2005
# 1           Jarno Trulli         ITA            TOYOTA    20.0  2005
# 2     Michael Schumacher         GER           FERRARI    10.0  2005
# 3   Giancarlo Fisichella         ITA           RENAULT    10.0  2005
# 4        Ralf Schumacher         GER            TOYOTA     9.0  2005
# 5            Mark Webber         AUS      WILLIAMS BMW     9.0  2005
# 6          Nick Heidfeld         GER      WILLIAMS BMW     9.0  2005
# 7        David Coulthard         GBR      RBR COSWORTH     9.0  2005
# 8     Juan Pablo Montoya         COL  MCLAREN MERCEDES     8.0  2005
# 9     Rubens Barrichello         BRA           FERRARI     8.0  2005
# 10        Kimi Räikkönen         FIN  MCLAREN MERCEDES     7.0  2005
# 11        Alexander Wurz         AUT  MCLAREN MERCEDES     6.0  2005
# 12    Jacques Villeneuve         CAN   SAUBER PETRONAS     5.0  2005
# ...

# %%
data06 = [
    [1, 'Fernando Alonso', 'ESP', 'RENAULT', 44],
    [2, 'Michael Schumacher', 'GER', 'FERRARI', 31],
    [3, 'Felipe Massa', 'BRA', 'FERRARI', 15],
    [4, 'Giancarlo Fisichella', 'ITA', 'RENAULT', 18],
    [5, 'Kimi Räikkönen', 'FIN', 'MCLAREN MERCEDES', 23],
    [6, 'Jenson Button', 'GBR', 'HONDA', 13],
    [7, 'Rubens Barrichello', 'BRA', 'HONDA', 6],
    [8, 'Juan Pablo Montoya', 'COL', 'MCLAREN MERCEDES', 15],
    [9, 'Nick Heidfeld', 'GER', 'SAUBER BMW', 5],
    [10, 'Ralf Schumacher', 'GER', 'TOYOTA', 7],
    [11, 'Pedro de la Rosa', 'ESP', 'MCLAREN MERCEDES', 0],
    [12, 'Jarno Trulli', 'ITA', 'TOYOTA', 0],
    [13, 'David Coulthard', 'GBR', 'RBR FERRARI', 1],
    [14, 'Mark Webber', 'AUS', 'WILLIAMS COSWORTH', 6],
    [15, 'Jacques Villeneuve', 'CAN', 'SAUBER BMW', 6],
    [16, 'Robert Kubica', 'POL', 'SAUBER BMW', 6],
    [17, 'Nico Rosberg', 'GER', 'WILLIAMS COSWORTH', 4],
    [18, 'Christian Klien', 'AUT', 'RBR FERRARI', 1],
    [19, 'Vitantonio Liuzzi', 'ITA', 'STR COSWORTH', 0],
    [20, 'Scott Speed', 'USA', 'STR COSWORTH', 0],
    [21, 'Tiago Monteiro', 'POR', 'MF1 TOYOTA', 0],
    [22, 'Christijan Albers', 'NED', 'MF1 TOYOTA', 0],
    [23, 'Takuma Sato', 'JPN', 'SUPER AGURI HONDA', 0],
    [24, 'Robert Doornbos', 'NED', 'RBR FERRARI', 0],
    [25, 'Yuji Ide', 'JPN', 'SUPER AGURI HONDA', 0],
    [26, 'Sakon Yamamoto', 'JPN', 'SUPER AGURI HONDA', 0],
    [27, 'Franck Montagny', 'FRA', 'SUPER AGURI HONDA', 0]
]

df06 = pd.DataFrame(data06, columns=['Pos', 'Driver', 'Nationality', 'Team', 'Points'])

df06['Year'] = '2006'
df06['Points'] = df06['Points'].astype(float)
df06 = df06.drop('Pos', axis=1)
df06 = df06.sort_values(by='Points', ascending=False)
df06 = df06.reset_index(drop=True)

df06
# Out:
#                   Driver Nationality               Team  Points  Year
# 0        Fernando Alonso         ESP            RENAULT    44.0  2006
# 1     Michael Schumacher         GER            FERRARI    31.0  2006
# 2         Kimi Räikkönen         FIN   MCLAREN MERCEDES    23.0  2006
# 3   Giancarlo Fisichella         ITA            RENAULT    18.0  2006
# 4           Felipe Massa         BRA            FERRARI    15.0  2006
# 5     Juan Pablo Montoya         COL   MCLAREN MERCEDES    15.0  2006
# 6          Jenson Button         GBR              HONDA    13.0  2006
# 7        Ralf Schumacher         GER             TOYOTA     7.0  2006
# 8          Robert Kubica         POL         SAUBER BMW     6.0  2006
# 9     Jacques Villeneuve         CAN         SAUBER BMW     6.0  2006
# 10           Mark Webber         AUS  WILLIAMS COSWORTH     6.0  2006
# 11    Rubens Barrichello         BRA              HONDA     6.0  2006
# ...

# %%
data07 = [
    ['Kimi Räikkönen', 'FIN', 'FERRARI', 22],
    ['Lewis Hamilton', 'GBR', 'MCLAREN MERCEDES', 22],
    ['Fernando Alonso', 'ESP', 'MCLAREN MERCEDES', 22],
    ['Felipe Massa', 'BRA', 'FERRARI', 17],
    ['Nick Heidfeld', 'GER', 'SAUBER BMW', 15],
    ['Robert Kubica', 'POL', 'SAUBER BMW', 3],
    ['Heikki Kovalainen', 'FIN', 'RENAULT', 1],
    ['Giancarlo Fisichella', 'ITA', 'RENAULT', 8],
    ['Nico Rosberg', 'GER', 'WILLIAMS TOYOTA', 2],
    ['David Coulthard', 'GBR', 'RED BULL RENAULT', 0],
    ['Alexander Wurz', 'AUT', 'WILLIAMS TOYOTA', 0],
    ['Mark Webber', 'AUS', 'RED BULL RENAULT', 0],
    ['Jarno Trulli', 'ITA', 'TOYOTA', 4],
    ['Sebastian Vettel', 'GER', 'STR FERRARI', 0],
    ['Jenson Button', 'GBR', 'HONDA', 0],
    ['Ralf Schumacher', 'GER', 'TOYOTA', 1],
    ['Takuma Sato', 'JPN', 'SUPER AGURI HONDA', 0],
    ['Vitantonio Liuzzi', 'ITA', 'STR FERRARI', 0],
    ['Adrian Sutil', 'GER', 'SPYKER FERRARI', 0],
    ['Rubens Barrichello', 'BRA', 'HONDA', 0],
    ['Scott Speed', 'USA', 'STR FERRARI', 0],
    ['Kazuki Nakajima', 'JPN', 'WILLIAMS TOYOTA', 0],
    ['Anthony Davidson', 'GBR', 'SUPER AGURI HONDA', 0],
    ['Sakon Yamamoto', 'JPN', 'SPYKER FERRARI', 0],
    ['Christijan Albers', 'NED', 'SPYKER FERRARI', 0]
]

df07 = pd.DataFrame(data07, columns=['Driver', 'Nationality', 'Team', 'Points'])

df07['Year'] = '2007'
df07['Points'] = df07['Points'].astype(float)
df07 = df07.sort_values(by='Points', ascending=False)
df07 = df07.reset_index(drop=True)

df07
# Out:
#                   Driver Nationality               Team  Points  Year
# 0         Kimi Räikkönen         FIN            FERRARI    22.0  2007
# 1        Fernando Alonso         ESP   MCLAREN MERCEDES    22.0  2007
# 2         Lewis Hamilton         GBR   MCLAREN MERCEDES    22.0  2007
# 3           Felipe Massa         BRA            FERRARI    17.0  2007
# 4          Nick Heidfeld         GER         SAUBER BMW    15.0  2007
# 5   Giancarlo Fisichella         ITA            RENAULT     8.0  2007
# 6           Jarno Trulli         ITA             TOYOTA     4.0  2007
# 7          Robert Kubica         POL         SAUBER BMW     3.0  2007
# 8           Nico Rosberg         GER    WILLIAMS TOYOTA     2.0  2007
# 9      Heikki Kovalainen         FIN            RENAULT     1.0  2007
# 10       Ralf Schumacher         GER             TOYOTA     1.0  2007
# 11          Adrian Sutil         GER     SPYKER FERRARI     0.0  2007
# ...

# %%
data08 = [
    ['Lewis Hamilton', 'GBR', 'MCLAREN MERCEDES', 14],
    ['Felipe Massa', 'BRA', 'FERRARI', 10],
    ['Kimi Räikkönen', 'FIN', 'FERRARI', 19],
    ['Robert Kubica', 'POL', 'SAUBER BMW', 14],
    ['Fernando Alonso', 'ESP', 'RENAULT', 6],
    ['Nick Heidfeld', 'GER', 'SAUBER BMW', 16],
    ['Heikki Kovalainen', 'FIN', 'MCLAREN MERCEDES', 14],
    ['Sebastian Vettel', 'GER', 'STR FERRARI', 0],
    ['Jarno Trulli', 'ITA', 'TOYOTA', 8],
    ['Timo Glock', 'GER', 'TOYOTA', 0],
    ['Mark Webber', 'AUS', 'RED BULL RENAULT', 4],
    ['Nelson Piquet', 'BRA', 'RENAULT', 0],
    ['Nico Rosberg', 'GER', 'WILLIAMS TOYOTA', 7],
    ['Rubens Barrichello', 'BRA', 'HONDA', 0],
    ['Kazuki Nakajima', 'JPN', 'WILLIAMS TOYOTA', 3],
    ['David Coulthard', 'GBR', 'RED BULL RENAULT', 0],
    ['Sebastien Bourdais', 'FRA', 'STR FERRARI', 2],
    ['Jenson Button', 'GBR', 'HONDA', 0],
    ['Giancarlo Fisichella', 'ITA', 'FORCE INDIA FERRARI', 0],
    ['Adrian Sutil', 'GER', 'FORCE INDIA FERRARI', 0],
    ['Takuma Sato', 'JPN', 'SUPER AGURI HONDA', 0],
    ['Anthony Davidson', 'GBR', 'SUPER AGURI HONDA', 0]
]

df08 = pd.DataFrame(data08, columns=['Driver', 'Nationality', 'Team', 'Points'])
df08['Year'] = '2008'
df08['Points'] = df08['Points'].astype(float)
df08 = df08.sort_values(by='Points', ascending=False).reset_index(drop=True)

df08
# Out:
#                   Driver Nationality                 Team  Points  Year
# 0         Kimi Räikkönen         FIN              FERRARI    19.0  2008
# 1          Nick Heidfeld         GER           SAUBER BMW    16.0  2008
# 2         Lewis Hamilton         GBR     MCLAREN MERCEDES    14.0  2008
# 3          Robert Kubica         POL           SAUBER BMW    14.0  2008
# 4      Heikki Kovalainen         FIN     MCLAREN MERCEDES    14.0  2008
# 5           Felipe Massa         BRA              FERRARI    10.0  2008
# 6           Jarno Trulli         ITA               TOYOTA     8.0  2008
# 7           Nico Rosberg         GER      WILLIAMS TOYOTA     7.0  2008
# 8        Fernando Alonso         ESP              RENAULT     6.0  2008
# 9            Mark Webber         AUS     RED BULL RENAULT     4.0  2008
# 10       Kazuki Nakajima         JPN      WILLIAMS TOYOTA     3.0  2008
# 11    Sebastien Bourdais         FRA          STR FERRARI     2.0  2008
# ...

# %%
data09 = [
    ['Jenson Button', 'GBR', 'BRAWN MERCEDES', 31],
    ['Sebastian Vettel', 'GER', 'RBR RENAULT', 18],
    ['Rubens Barrichello', 'BRA', 'BRAWN MERCEDES', 19],
    ['Mark Webber', 'AUS', 'RBR RENAULT', 9.5],
    ['Lewis Hamilton', 'GBR', 'MCLAREN MERCEDES', 9],
    ['Kimi Räikkönen', 'FIN', 'FERRARI', 3],
    ['Nico Rosberg', 'GER', 'WILLIAMS TOYOTA', 3.5],
    ['Jarno Trulli', 'ITA', 'TOYOTA', 14.5],
    ['Fernando Alonso', 'ESP', 'RENAULT', 5],
    ['Timo Glock', 'GER', 'TOYOTA', 12],
    ['Felipe Massa', 'BRA', 'FERRARI', 0],
    ['Heikki Kovalainen', 'FIN', 'MCLAREN MERCEDES', 4],
    ['Nick Heidfeld', 'GER', 'SAUBER BMW', 4],
    ['Robert Kubica', 'POL', 'SAUBER BMW', 0],
    ['Giancarlo Fisichella', 'ITA', 'FERRARI', 0],
    ['Sebastien Buemi', 'SUI', 'STR FERRARI', 3],
    ['Adrian Sutil', 'GER', 'FORCE INDIA MERCEDES', 0],
    ['Kamui Kobayashi', 'JPN', 'TOYOTA', 0],
    ['Sebastien Bourdais', 'FRA', 'STR FERRARI', 1],
    ['Kazuki Nakajima', 'JPN', 'WILLIAMS TOYOTA', 0],
    ['Nelson Piquet', 'BRA', 'RENAULT', 0],
    ['Vitantonio Liuzzi', 'ITA', 'FORCE INDIA MERCEDES', 0],
    ['Romain Grosjean', 'FRA', 'RENAULT', 0],
    ['Jaime Alguersuari', 'ESP', 'STR FERRARI', 0],
    ['Luca Badoer', 'ITA', 'FERRARI', 0]
]

df09 = pd.DataFrame(data09, columns=['Driver', 'Nationality', 'Team', 'Points'])
df09['Year'] = '2009'
df09['Points'] = df09['Points'].astype(float)
df09 = df09.sort_values(by='Points', ascending=False).reset_index(drop=True)

df09
# Out:
#                   Driver Nationality                  Team  Points  Year
# 0          Jenson Button         GBR        BRAWN MERCEDES    31.0  2009
# 1     Rubens Barrichello         BRA        BRAWN MERCEDES    19.0  2009
# 2       Sebastian Vettel         GER           RBR RENAULT    18.0  2009
# 3           Jarno Trulli         ITA                TOYOTA    14.5  2009
# 4             Timo Glock         GER                TOYOTA    12.0  2009
# 5            Mark Webber         AUS           RBR RENAULT     9.5  2009
# 6         Lewis Hamilton         GBR      MCLAREN MERCEDES     9.0  2009
# 7        Fernando Alonso         ESP               RENAULT     5.0  2009
# 8      Heikki Kovalainen         FIN      MCLAREN MERCEDES     4.0  2009
# 9          Nick Heidfeld         GER            SAUBER BMW     4.0  2009
# 10          Nico Rosberg         GER       WILLIAMS TOYOTA     3.5  2009
# 11        Kimi Räikkönen         FIN               FERRARI     3.0  2009
# ...

# %%
data10 = [
    ['Sebastian Vettel', 'GER', 'RBR RENAULT', 45],
    ['Fernando Alonso', 'ESP', 'FERRARI', 49],
    ['Mark Webber', 'AUS', 'RBR RENAULT', 28],
    ['Lewis Hamilton', 'GBR', 'MCLAREN MERCEDES', 49],
    ['Jenson Button', 'GBR', 'MCLAREN MERCEDES', 60],
    ['Felipe Massa', 'BRA', 'FERRARI', 41],
    ['Nico Rosberg', 'GER', 'MERCEDES', 50],
    ['Robert Kubica', 'POL', 'RENAULT', 40],
    ['Michael Schumacher', 'GER', 'MERCEDES', 10],
    ['Rubens Barrichello', 'BRA', 'WILLIAMS COSWORTH', 5],
    ['Adrian Sutil', 'GER', 'FORCE INDIA MERCEDES', 10],
    ['Kamui Kobayashi', 'JPN', 'SAUBER FERRARI', 0],
    ['Vitaly Petrov', 'RUS', 'RENAULT', 0],
    ['Nico Hulkenberg', 'GER', 'WILLIAMS COSWORTH', 1],
    ['Vitantonio Liuzzi', 'ITA', 'FORCE INDIA MERCEDES', 8],
    ['Sebastien Buemi', 'SUI', 'STR FERRARI', 0],
    ['Pedro de la Rosa', 'ESP', 'SAUBER FERRARI', 0],
    ['Nick Heidfeld', 'GER', 'SAUBER FERRARI', 0],
    ['Jaime Alguersuari', 'ESP', 'STR FERRARI', 2],
    ['Heikki Kovalainen', 'FIN', 'LOTUS COSWORTH', 0],
    ['Jarno Trulli', 'ITA', 'LOTUS COSWORTH', 0],
    ['Karun Chandhok', 'IND', 'HRT COSWORTH', 0],
    ['Bruno Senna', 'BRA', 'HRT COSWORTH', 0],
    ['Lucas di Grassi', 'BRA', 'VIRGIN COSWORTH', 0],
    ['Timo Glock', 'GER', 'VIRGIN COSWORTH', 0],
    ['Sakon Yamamoto', 'JPN', 'HRT COSWORTH', 0],
    ['Christian Klien', 'AUT', 'HRT COSWORTH', 0]
]

df10 = pd.DataFrame(data10, columns=['Driver', 'Nationality', 'Team', 'Points'])
df10['Year'] = '2010'
df10['Points'] = df10['Points'].astype(float)
df10 = df10.sort_values(by='Points', ascending=False).reset_index(drop=True)

df10
# Out:
#                 Driver Nationality                  Team  Points  Year
# 0        Jenson Button         GBR      MCLAREN MERCEDES    60.0  2010
# 1         Nico Rosberg         GER              MERCEDES    50.0  2010
# 2      Fernando Alonso         ESP               FERRARI    49.0  2010
# 3       Lewis Hamilton         GBR      MCLAREN MERCEDES    49.0  2010
# 4     Sebastian Vettel         GER           RBR RENAULT    45.0  2010
# 5         Felipe Massa         BRA               FERRARI    41.0  2010
# 6        Robert Kubica         POL               RENAULT    40.0  2010
# 7          Mark Webber         AUS           RBR RENAULT    28.0  2010
# 8   Michael Schumacher         GER              MERCEDES    10.0  2010
# 9         Adrian Sutil         GER  FORCE INDIA MERCEDES    10.0  2010
# 10   Vitantonio Liuzzi         ITA  FORCE INDIA MERCEDES     8.0  2010
# 11  Rubens Barrichello         BRA     WILLIAMS COSWORTH     5.0  2010
# ...

# %%
data11 = [
    ['Sebastian Vettel', 'GER', 'RED BULL RACING RENAULT', 93],
    ['Jenson Button', 'GBR', 'MCLAREN MERCEDES', 46],
    ['Mark Webber', 'AUS', 'RED BULL RACING RENAULT', 55],
    ['Fernando Alonso', 'ESP', 'FERRARI', 41],
    ['Lewis Hamilton', 'GBR', 'MCLAREN MERCEDES', 59],
    ['Felipe Massa', 'BRA', 'FERRARI', 24],
    ['Nico Rosberg', 'GER', 'MERCEDES', 20],
    ['Michael Schumacher', 'GER', 'MERCEDES', 6],
    ['Adrian Sutil', 'GER', 'FORCE INDIA MERCEDES', 2],
    ['Vitaly Petrov', 'RUS', 'RENAULT', 21],
    ['Nick Heidfeld', 'GER', 'RENAULT', 21],
    ['Kamui Kobayashi', 'JPN', 'SAUBER FERRARI', 8],
    ['Paul di Resta', 'GBR', 'FORCE INDIA MERCEDES', 2],
    ['Jaime Alguersuari', 'ESP', 'STR FERRARI', 0],
    ['Sebastien Buemi', 'SUI', 'STR FERRARI', 6],
    ['Sergio Perez', 'MEX', 'SAUBER FERRARI', 0],
    ['Rubens Barrichello', 'BRA', 'WILLIAMS COSWORTH', 0],
    ['Bruno Senna', 'BRA', 'RENAULT', 0],
    ['Pastor Maldonado', 'VEN', 'WILLIAMS COSWORTH', 0],
    ['Pedro de la Rosa', 'ESP', 'SAUBER FERRARI', 0],
    ['Jarno Trulli', 'ITA', 'LOTUS RENAULT', 0],
    ['Heikki Kovalainen', 'FIN', 'LOTUS RENAULT', 0],
    ['Vitantonio Liuzzi', 'ITA', 'HRT COSWORTH', 0],
    ['Jerome d\'Ambrosio', 'BEL', 'VIRGIN COSWORTH', 0],
    ['Timo Glock', 'GER', 'VIRGIN COSWORTH', 0],
    ['Narain Karthikeyan', 'IND', 'HRT COSWORTH', 0],
    ['Daniel Ricciardo', 'AUS', 'HRT COSWORTH', 0],
    ['Karun Chandhok', 'IND', 'LOTUS RENAULT', 0]
]

df11 = pd.DataFrame(data11, columns=['Driver', 'Nationality', 'Team', 'Points'])
df11['Year'] = '2011'
df11['Points'] = df11['Points'].astype(float)
df11 = df11.sort_values(by='Points', ascending=False).reset_index(drop=True)

df11
# Out:
#                 Driver Nationality                     Team  Points  Year
# 0     Sebastian Vettel         GER  RED BULL RACING RENAULT    93.0  2011
# 1       Lewis Hamilton         GBR         MCLAREN MERCEDES    59.0  2011
# 2          Mark Webber         AUS  RED BULL RACING RENAULT    55.0  2011
# 3        Jenson Button         GBR         MCLAREN MERCEDES    46.0  2011
# 4      Fernando Alonso         ESP                  FERRARI    41.0  2011
# 5         Felipe Massa         BRA                  FERRARI    24.0  2011
# 6        Nick Heidfeld         GER                  RENAULT    21.0  2011
# 7        Vitaly Petrov         RUS                  RENAULT    21.0  2011
# 8         Nico Rosberg         GER                 MERCEDES    20.0  2011
# 9      Kamui Kobayashi         JPN           SAUBER FERRARI     8.0  2011
# 10     Sebastien Buemi         SUI              STR FERRARI     6.0  2011
# 11  Michael Schumacher         GER                 MERCEDES     6.0  2011
# ...

# %%
data12 = [
    ['Sebastian Vettel', 'GER', 'RED BULL RACING RENAULT', 53],
    ['Fernando Alonso', 'ESP', 'FERRARI', 43],
    ['Kimi Räikkönen', 'FIN', 'LOTUS RENAULT', 34],
    ['Lewis Hamilton', 'GBR', 'MCLAREN MERCEDES', 49],
    ['Jenson Button', 'GBR', 'MCLAREN MERCEDES', 43],
    ['Mark Webber', 'AUS', 'RED BULL RACING RENAULT', 48],
    ['Felipe Massa', 'BRA', 'FERRARI', 2],
    ['Romain Grosjean', 'FRA', 'LOTUS RENAULT', 23],
    ['Nico Rosberg', 'GER', 'MERCEDES', 35],
    ['Sergio Perez', 'MEX', 'SAUBER FERRARI', 22],
    ['Nico Hulkenberg', 'GER', 'FORCE INDIA MERCEDES', 2],
    ['Kamui Kobayashi', 'JPN', 'SAUBER FERRARI', 9],
    ['Michael Schumacher', 'GER', 'MERCEDES', 2],
    ['Paul di Resta', 'GBR', 'FORCE INDIA MERCEDES', 15],
    ['Pastor Maldonado', 'VEN', 'WILLIAMS RENAULT', 4],
    ['Bruno Senna', 'BRA', 'WILLIAMS RENAULT', 12],
    ['Jean-Eric Vergne', 'FRA', 'STR FERRARI', 4],
    ['Daniel Ricciardo', 'AUS', 'STR FERRARI', 2],
    ['Vitaly Petrov', 'RUS', 'CATERHAM RENAULT', 0],
    ['Timo Glock', 'GER', 'MARUSSIA COSWORTH', 0],
    ['Charles Pic', 'FRA', 'MARUSSIA COSWORTH', 0],
    ['Heikki Kovalainen', 'FIN', 'CATERHAM RENAULT', 0],
    ['Jerome d\'Ambrosio', 'BEL', 'LOTUS RENAULT', 0],
    ['Narain Karthikeyan', 'IND', 'HRT COSWORTH', 0],
    ['Pedro de la Rosa', 'ESP', 'HRT COSWORTH', 0]
]

df12 = pd.DataFrame(data12, columns=['Driver', 'Nationality', 'Team', 'Points'])
df12['Year'] = '2012'
df12['Points'] = df12['Points'].astype(float)
df12 = df12.sort_values(by='Points', ascending=False).reset_index(drop=True)

df12
# Out:
#                 Driver Nationality                     Team  Points  Year
# 0     Sebastian Vettel         GER  RED BULL RACING RENAULT    53.0  2012
# 1       Lewis Hamilton         GBR         MCLAREN MERCEDES    49.0  2012
# 2          Mark Webber         AUS  RED BULL RACING RENAULT    48.0  2012
# 3        Jenson Button         GBR         MCLAREN MERCEDES    43.0  2012
# 4      Fernando Alonso         ESP                  FERRARI    43.0  2012
# 5         Nico Rosberg         GER                 MERCEDES    35.0  2012
# 6       Kimi Räikkönen         FIN            LOTUS RENAULT    34.0  2012
# 7      Romain Grosjean         FRA            LOTUS RENAULT    23.0  2012
# 8         Sergio Perez         MEX           SAUBER FERRARI    22.0  2012
# 9        Paul di Resta         GBR     FORCE INDIA MERCEDES    15.0  2012
# 10         Bruno Senna         BRA         WILLIAMS RENAULT    12.0  2012
# 11     Kamui Kobayashi         JPN           SAUBER FERRARI     9.0  2012
# ...

# %%
data13 = [
    ['Sebastian Vettel', 'GER', 'RED BULL RACING RENAULT', 77],
    ['Fernando Alonso', 'ESP', 'FERRARI', 47],
    ['Mark Webber', 'AUS', 'RED BULL RACING RENAULT', 32],
    ['Lewis Hamilton', 'GBR', 'MERCEDES', 50],
    ['Kimi Räikkönen', 'FIN', 'LOTUS RENAULT', 67],
    ['Nico Rosberg', 'GER', 'MERCEDES', 14],
    ['Romain Grosjean', 'FRA', 'LOTUS RENAULT', 26],
    ['Felipe Massa', 'BRA', 'FERRARI', 30],
    ['Jenson Button', 'GBR', 'MCLAREN MERCEDES', 13],
    ['Nico Hulkenberg', 'GER', 'SAUBER FERRARI', 5],
    ['Sergio Perez', 'MEX', 'MCLAREN MERCEDES', 10],
    ['Paul di Resta', 'GBR', 'FORCE INDIA MERCEDES', 20],
    ['Adrian Sutil', 'GER', 'FORCE INDIA MERCEDES', 6],
    ['Daniel Ricciardo', 'AUS', 'STR FERRARI', 6],
    ['Jean-Eric Vergne', 'FRA', 'STR FERRARI', 1],
    ['Esteban Gutierrez', 'MEX', 'SAUBER FERRARI', 0],
    ['Valtteri Bottas', 'FIN', 'WILLIAMS RENAULT', 0],
    ['Pastor Maldonado', 'VEN', 'WILLIAMS RENAULT', 0],
    ['Jules Bianchi', 'FRA', 'MARUSSIA COSWORTH', 0],
    ['Charles Pic', 'FRA', 'CATERHAM RENAULT', 0],
    ['Heikki Kovalainen', 'FIN', 'LOTUS RENAULT', 0],
    ['Giedo van der Garde', 'NED', 'CATERHAM RENAULT', 0],
    ['Max Chilton', 'GBR', 'MARUSSIA COSWORTH', 0]
]

df13 = pd.DataFrame(data13, columns=['Driver', 'Nationality', 'Team', 'Points'])
df13['Year'] = '2013'
df13['Points'] = df13['Points'].astype(float)
df13 = df13.sort_values(by='Points', ascending=False).reset_index(drop=True)

df13
# Out:
#                  Driver Nationality                     Team  Points  Year
# 0      Sebastian Vettel         GER  RED BULL RACING RENAULT    77.0  2013
# 1        Kimi Räikkönen         FIN            LOTUS RENAULT    67.0  2013
# 2        Lewis Hamilton         GBR                 MERCEDES    50.0  2013
# 3       Fernando Alonso         ESP                  FERRARI    47.0  2013
# 4           Mark Webber         AUS  RED BULL RACING RENAULT    32.0  2013
# 5          Felipe Massa         BRA                  FERRARI    30.0  2013
# 6       Romain Grosjean         FRA            LOTUS RENAULT    26.0  2013
# 7         Paul di Resta         GBR     FORCE INDIA MERCEDES    20.0  2013
# 8          Nico Rosberg         GER                 MERCEDES    14.0  2013
# 9         Jenson Button         GBR         MCLAREN MERCEDES    13.0  2013
# 10         Sergio Perez         MEX         MCLAREN MERCEDES    10.0  2013
# ...

# %%
data14 = [
    ['Lewis Hamilton', 'GBR', 'MERCEDES', 75],
    ['Nico Rosberg', 'GER', 'MERCEDES', 79],
    ['Daniel Ricciardo', 'AUS', 'RED BULL RACING RENAULT', 24],
    ['Valtteri Bottas', 'FIN', 'WILLIAMS MERCEDES', 24],
    ['Sebastian Vettel', 'GER', 'RED BULL RACING RENAULT', 33],
    ['Fernando Alonso', 'ESP', 'FERRARI', 41],
    ['Felipe Massa', 'BRA', 'WILLIAMS MERCEDES', 12],
    ['Jenson Button', 'GBR', 'MCLAREN MERCEDES', 23],
    ['Nico Hulkenberg', 'GER', 'FORCE INDIA MERCEDES', 36],
    ['Sergio Perez', 'MEX', 'FORCE INDIA MERCEDES', 18],
    ['Kevin Magnussen', 'DEN', 'MCLAREN MERCEDES', 20],
    ['Kimi Räikkönen', 'FIN', 'FERRARI', 11],
    ['Jean-Eric Vergne', 'FRA', 'STR RENAULT', 4],
    ['Romain Grosjean', 'FRA', 'LOTUS RENAULT', 0],
    ['Daniil Kvyat', 'RUS', 'STR RENAULT', 4],
    ['Pastor Maldonado', 'VEN', 'LOTUS RENAULT', 0],
    ['Jules Bianchi', 'FRA', 'MARUSSIA FERRARI', 0],
    ['Adrian Sutil', 'GER', 'SAUBER FERRARI', 0],
    ['Marcus Ericsson', 'SWE', 'CATERHAM RENAULT', 0],
    ['Esteban Gutierrez', 'MEX', 'SAUBER FERRARI', 0],
    ['Max Chilton', 'GBR', 'MARUSSIA FERRARI', 0],
    ['Kamui Kobayashi', 'JPN', 'CATERHAM RENAULT', 0],
    ['Will Stevens', 'GBR', 'CATERHAM RENAULT', 0]
]

df14 = pd.DataFrame(data14, columns=['Driver', 'Nationality', 'Team', 'Points'])
df14['Year'] = '2014'
df14['Points'] = df14['Points'].astype(float)
df14 = df14.sort_values(by='Points', ascending=False).reset_index(drop=True)

df14
# Out:
#                Driver Nationality                     Team  Points  Year
# 0        Nico Rosberg         GER                 MERCEDES    79.0  2014
# 1      Lewis Hamilton         GBR                 MERCEDES    75.0  2014
# 2     Fernando Alonso         ESP                  FERRARI    41.0  2014
# 3     Nico Hulkenberg         GER     FORCE INDIA MERCEDES    36.0  2014
# 4    Sebastian Vettel         GER  RED BULL RACING RENAULT    33.0  2014
# 5    Daniel Ricciardo         AUS  RED BULL RACING RENAULT    24.0  2014
# 6     Valtteri Bottas         FIN        WILLIAMS MERCEDES    24.0  2014
# 7       Jenson Button         GBR         MCLAREN MERCEDES    23.0  2014
# 8     Kevin Magnussen         DEN         MCLAREN MERCEDES    20.0  2014
# 9        Sergio Perez         MEX     FORCE INDIA MERCEDES    18.0  2014
# 10       Felipe Massa         BRA        WILLIAMS MERCEDES    12.0  2014
# 11     Kimi Räikkönen         FIN                  FERRARI    11.0  2014
# ...

# %%
data15 = [
    ['Lewis Hamilton', 'GBR', 'MERCEDES', 93],
    ['Nico Rosberg', 'GER', 'MERCEDES', 66],
    ['Sebastian Vettel', 'GER', 'FERRARI', 65],
    ['Kimi Räikkönen', 'FIN', 'FERRARI', 42],
    ['Valtteri Bottas', 'FIN', 'WILLIAMS MERCEDES', 30],
    ['Felipe Massa', 'BRA', 'WILLIAMS MERCEDES', 31],
    ['Daniil Kvyat', 'RUS', 'RED BULL RACING RENAULT', 4],
    ['Daniel Ricciardo', 'AUS', 'RED BULL RACING RENAULT', 19],
    ['Sergio Perez', 'MEX', 'FORCE INDIA MERCEDES', 5],
    ['Nico Hulkenberg', 'GER', 'FORCE INDIA MERCEDES', 6],
    ['Romain Grosjean', 'FRA', 'LOTUS MERCEDES', 12],
    ['Max Verstappen', 'NED', 'STR RENAULT', 6],
    ['Felipe Nasr', 'BRA', 'SAUBER FERRARI', 14],
    ['Pastor Maldonado', 'VEN', 'LOTUS MERCEDES', 0],
    ['Carlos Sainz', 'ESP', 'STR RENAULT', 6],
    ['Jenson Button', 'GBR', 'MCLAREN HONDA', 0],
    ['Fernando Alonso', 'ESP', 'MCLAREN HONDA', 0],
    ['Marcus Ericsson', 'SWE', 'SAUBER FERRARI', 5],
    ['Roberto Merhi', 'ESP', 'MARUSSIA FERRARI', 0],
    ['Alexander Rossi', 'USA', 'MARUSSIA FERRARI', 0],
    ['Will Stevens', 'GBR', 'MARUSSIA FERRARI', 0]
]

df15 = pd.DataFrame(data15, columns=['Driver', 'Nationality', 'Team', 'Points'])
df15['Year'] = '2015'
df15['Points'] = df15['Points'].astype(float)
df15 = df15.sort_values(by='Points', ascending=False).reset_index(drop=True)

df15
# Out:
#               Driver Nationality                     Team  Points  Year
# 0     Lewis Hamilton         GBR                 MERCEDES    93.0  2015
# 1       Nico Rosberg         GER                 MERCEDES    66.0  2015
# 2   Sebastian Vettel         GER                  FERRARI    65.0  2015
# 3     Kimi Räikkönen         FIN                  FERRARI    42.0  2015
# 4       Felipe Massa         BRA        WILLIAMS MERCEDES    31.0  2015
# 5    Valtteri Bottas         FIN        WILLIAMS MERCEDES    30.0  2015
# 6   Daniel Ricciardo         AUS  RED BULL RACING RENAULT    19.0  2015
# 7        Felipe Nasr         BRA           SAUBER FERRARI    14.0  2015
# 8    Romain Grosjean         FRA           LOTUS MERCEDES    12.0  2015
# 9    Nico Hulkenberg         GER     FORCE INDIA MERCEDES     6.0  2015
# 10    Max Verstappen         NED              STR RENAULT     6.0  2015
# 11      Carlos Sainz         ESP              STR RENAULT     6.0  2015
# ...

# %%
data16 = [
    ['Nico Rosberg', 'GER', 'MERCEDES', 100],
    ['Lewis Hamilton', 'GBR', 'MERCEDES', 57],
    ['Daniel Ricciardo', 'AUS', 'RED BULL RACING TAG HEUER', 36],
    ['Sebastian Vettel', 'GER', 'FERRARI', 33],
    ['Max Verstappen', 'NED', 'RED BULL RACING TAG HEUER', 13],
    ['Kimi Räikkönen', 'FIN', 'FERRARI', 43],
    ['Sergio Perez', 'MEX', 'FORCE INDIA MERCEDES', 2],
    ['Valtteri Bottas', 'FIN', 'WILLIAMS MERCEDES', 19],
    ['Nico Hulkenberg', 'GER', 'FORCE INDIA MERCEDES', 6],
    ['Fernando Alonso', 'ESP', 'MCLAREN HONDA', 8],
    ['Felipe Massa', 'BRA', 'WILLIAMS MERCEDES', 32],
    ['Carlos Sainz', 'ESP', 'TORO ROSSO FERRARI', 4],
    ['Romain Grosjean', 'FRA', 'HAAS FERRARI', 22],
    ['Daniil Kvyat', 'RUS', 'TORO ROSSO FERRARI', 21],
    ['Jenson Button', 'GBR', 'MCLAREN HONDA', 1],
    ['Kevin Magnussen', 'DEN', 'RENAULT', 6],
    ['Felipe Nasr', 'BRA', 'SAUBER FERRARI', 0],
    ['Jolyon Palmer', 'GBR', 'RENAULT', 0],
    ['Pascal Wehrlein', 'GER', 'MRT MERCEDES', 0],
    ['Stoffel Vandoorne', 'BEL', 'MCLAREN HONDA', 1],
    ['Esteban Gutierrez', 'MEX', 'HAAS FERRARI', 0],
    ['Marcus Ericsson', 'SWE', 'SAUBER FERRARI', 0],
    ['Esteban Ocon', 'FRA', 'MRT MERCEDES', 0],
    ['Rio Haryanto', 'INA', 'MRT MERCEDES', 0]
]

df16 = pd.DataFrame(data16, columns=['Driver', 'Nationality', 'Team', 'Points'])
df16['Year'] = '2016'
df16['Points'] = df16['Points'].astype(float)
df16 = df16.sort_values(by='Points', ascending=False).reset_index(drop=True)

df16
# Out:
#                Driver Nationality                       Team  Points  Year
# 0        Nico Rosberg         GER                   MERCEDES   100.0  2016
# 1      Lewis Hamilton         GBR                   MERCEDES    57.0  2016
# 2      Kimi Räikkönen         FIN                    FERRARI    43.0  2016
# 3    Daniel Ricciardo         AUS  RED BULL RACING TAG HEUER    36.0  2016
# 4    Sebastian Vettel         GER                    FERRARI    33.0  2016
# 5        Felipe Massa         BRA          WILLIAMS MERCEDES    32.0  2016
# 6     Romain Grosjean         FRA               HAAS FERRARI    22.0  2016
# 7        Daniil Kvyat         RUS         TORO ROSSO FERRARI    21.0  2016
# 8     Valtteri Bottas         FIN          WILLIAMS MERCEDES    19.0  2016
# 9      Max Verstappen         NED  RED BULL RACING TAG HEUER    13.0  2016
# 10    Fernando Alonso         ESP              MCLAREN HONDA     8.0  2016
# ...

# %%
data17 = [
    ['Lewis Hamilton', 'GBR', 'MERCEDES', 73],
    ['Sebastian Vettel', 'GER', 'FERRARI', 86],
    ['Valtteri Bottas', 'FIN', 'MERCEDES', 63],
    ['Kimi Räikkönen', 'FIN', 'FERRARI', 49],
    ['Daniel Ricciardo', 'AUS', 'RED BULL RACING TAG HEUER', 22],
    ['Max Verstappen', 'NED', 'RED BULL RACING TAG HEUER', 35],
    ['Sergio Perez', 'MEX', 'FORCE INDIA MERCEDES', 22],
    ['Esteban Ocon', 'FRA', 'FORCE INDIA MERCEDES', 9],
    ['Carlos Sainz', 'ESP', 'RENAULT', 11],
    ['Nico Hulkenberg', 'GER', 'RENAULT', 6],
    ['Felipe Massa', 'BRA', 'WILLIAMS MERCEDES', 18],
    ['Lance Stroll', 'CAN', 'WILLIAMS MERCEDES', 0],
    ['Romain Grosjean', 'FRA', 'HAAS FERRARI', 4],
    ['Kevin Magnussen', 'DEN', 'HAAS FERRARI', 4],
    ['Fernando Alonso', 'ESP', 'MCLAREN HONDA', 0],
    ['Stoffel Vandoorne', 'BEL', 'MCLAREN HONDA', 0],
    ['Jolyon Palmer', 'GBR', 'RENAULT', 0],
    ['Pascal Wehrlein', 'GER', 'SAUBER FERRARI', 0],
    ['Daniil Kvyat', 'RUS', 'TORO ROSSO', 2],
    ['Marcus Ericsson', 'SWE', 'SAUBER FERRARI', 0],
    ['Pierre Gasly', 'FRA', 'TORO ROSSO', 0],
    ['Antonio Giovinazzi', 'ITA', 'SAUBER FERRARI', 0],
    ['Brendon Hartley', 'NZL', 'TORO ROSSO', 0]
]

df17 = pd.DataFrame(data17, columns=['Driver', 'Nationality', 'Team', 'Points'])
df17['Year'] = '2017'
df17['Points'] = df17['Points'].astype(float)
df17 = df17.sort_values(by='Points', ascending=False).reset_index(drop=True)

df17
# Out:
#                 Driver Nationality                       Team  Points  Year
# 0     Sebastian Vettel         GER                    FERRARI    86.0  2017
# 1       Lewis Hamilton         GBR                   MERCEDES    73.0  2017
# 2      Valtteri Bottas         FIN                   MERCEDES    63.0  2017
# 3       Kimi Räikkönen         FIN                    FERRARI    49.0  2017
# 4       Max Verstappen         NED  RED BULL RACING TAG HEUER    35.0  2017
# 5     Daniel Ricciardo         AUS  RED BULL RACING TAG HEUER    22.0  2017
# 6         Sergio Perez         MEX       FORCE INDIA MERCEDES    22.0  2017
# 7         Felipe Massa         BRA          WILLIAMS MERCEDES    18.0  2017
# 8         Carlos Sainz         ESP                    RENAULT    11.0  2017
# 9         Esteban Ocon         FRA       FORCE INDIA MERCEDES     9.0  2017
# 10     Nico Hulkenberg         GER                    RENAULT     6.0  2017
# ...

# %%
data18 = [
    ['Lewis Hamilton', 'GBR', 'MERCEDES', 70],
    ['Sebastian Vettel', 'GER', 'FERRARI', 66],
    ['Kimi Räikkönen', 'FIN', 'FERRARI', 48],
    ['Max Verstappen', 'NED', 'RED BULL RACING TAG HEUER', 18],
    ['Valtteri Bottas', 'FIN', 'MERCEDES', 40],
    ['Daniel Ricciardo', 'AUS', 'RED BULL RACING TAG HEUER', 37],
    ['Nico Hulkenberg', 'GER', 'RENAULT', 22],
    ['Sergio Perez', 'MEX', 'FORCE INDIA MERCEDES', 15],
    ['Kevin Magnussen', 'DEN', 'HAAS FERRARI', 11],
    ['Carlos Sainz', 'ESP', 'RENAULT', 13],
    ['Fernando Alonso', 'ESP', 'MCLAREN RENAULT', 18],
    ['Esteban Ocon', 'FRA', 'FORCE INDIA MERCEDES', 1],
    ['Charles Leclerc', 'MON', 'SAUBER FERRARI', 8],
    ['Romain Grosjean', 'FRA', 'HAAS FERRARI', 0],
    ['Pierre Gasly', 'FRA', 'SCUDERIA TORO ROSSO HONDA', 12],
    ['Stoffel Vandoorne', 'BEL', 'MCLAREN RENAULT', 8],
    ['Marcus Ericsson', 'SWE', 'SAUBER FERRARI', 2],
    ['Lance Stroll', 'CAN', 'WILLIAMS MERCEDES', 4],
    ['Brendon Hartley', 'NZL', 'SCUDERIA TORO ROSSO HONDA', 1],
    ['Sergey Sirotkin', 'RUS', 'WILLIAMS MERCEDES', 0]
]

df18 = pd.DataFrame(data18, columns=['Driver', 'Nationality', 'Team', 'Points'])
df18['Year'] = '2018'
df18['Points'] = df18['Points'].astype(float)
df18 = df18.sort_values(by='Points', ascending=False).reset_index(drop=True)

df18
# Out:
#                Driver Nationality                       Team  Points  Year
# 0      Lewis Hamilton         GBR                   MERCEDES    70.0  2018
# 1    Sebastian Vettel         GER                    FERRARI    66.0  2018
# 2      Kimi Räikkönen         FIN                    FERRARI    48.0  2018
# 3     Valtteri Bottas         FIN                   MERCEDES    40.0  2018
# 4    Daniel Ricciardo         AUS  RED BULL RACING TAG HEUER    37.0  2018
# 5     Nico Hulkenberg         GER                    RENAULT    22.0  2018
# 6     Fernando Alonso         ESP            MCLAREN RENAULT    18.0  2018
# 7      Max Verstappen         NED  RED BULL RACING TAG HEUER    18.0  2018
# 8        Sergio Perez         MEX       FORCE INDIA MERCEDES    15.0  2018
# 9        Carlos Sainz         ESP                    RENAULT    13.0  2018
# 10       Pierre Gasly         FRA  SCUDERIA TORO ROSSO HONDA    12.0  2018
# ...

# %%
data19 = [
    ['Lewis Hamilton', 'GBR', 'MERCEDES', 86],
    ['Valtteri Bottas', 'FIN', 'MERCEDES', 87],
    ['Max Verstappen', 'NED', 'RED BULL RACING HONDA', 51],
    ['Charles Leclerc', 'MON', 'FERRARI', 47],
    ['Sebastian Vettel', 'GER', 'FERRARI', 52],
    ['Carlos Sainz', 'ESP', 'MCLAREN RENAULT', 6],
    ['Pierre Gasly', 'FRA', 'SCUDERIA TORO ROSSO HONDA', 13],
    ['Alexander Albon', 'THA', 'RED BULL RACING HONDA', 3],
    ['Daniel Ricciardo', 'AUS', 'RENAULT', 6],
    ['Sergio Perez', 'MEX', 'RACING POINT BWT MERCEDES', 13],
    ['Lando Norris', 'GBR', 'MCLAREN RENAULT', 12],
    ['Kimi Räikkönen', 'FIN', 'ALFA ROMEO RACING FERRARI', 13],
    ['Daniil Kvyat', 'RUS', 'SCUDERIA TORO ROSSO HONDA', 1],
    ['Nico Hulkenberg', 'GER', 'RENAULT', 6],
    ['Lance Stroll', 'CAN', 'RACING POINT BWT MERCEDES', 4],
    ['Kevin Magnussen', 'DEN', 'HAAS FERRARI', 8],
    ['Antonio Giovinazzi', 'ITA', 'ALFA ROMEO RACING FERRARI', 0],
    ['Romain Grosjean', 'FRA', 'HAAS FERRARI', 0],
    ['Robert Kubica', 'POL', 'WILLIAMS MERCEDES', 0],
    ['George Russell', 'GBR', 'WILLIAMS MERCEDES', 0]
]

df19 = pd.DataFrame(data19, columns=['Driver', 'Nationality', 'Team', 'Points'])
df19['Year'] = '2019'
df19['Points'] = df19['Points'].astype(float)
df19 = df19.sort_values(by='Points', ascending=False).reset_index(drop=True)

df19
# Out:
#                 Driver Nationality                       Team  Points  Year
# 0      Valtteri Bottas         FIN                   MERCEDES    87.0  2019
# 1       Lewis Hamilton         GBR                   MERCEDES    86.0  2019
# 2     Sebastian Vettel         GER                    FERRARI    52.0  2019
# 3       Max Verstappen         NED      RED BULL RACING HONDA    51.0  2019
# 4      Charles Leclerc         MON                    FERRARI    47.0  2019
# 5         Sergio Perez         MEX  RACING POINT BWT MERCEDES    13.0  2019
# 6       Kimi Räikkönen         FIN  ALFA ROMEO RACING FERRARI    13.0  2019
# 7         Pierre Gasly         FRA  SCUDERIA TORO ROSSO HONDA    13.0  2019
# 8         Lando Norris         GBR            MCLAREN RENAULT    12.0  2019
# 9      Kevin Magnussen         DEN               HAAS FERRARI     8.0  2019
# 10    Daniel Ricciardo         AUS                    RENAULT     6.0  2019
# ...

# %%
data20 = [
    ['Lewis Hamilton', 'GBR', 'MERCEDES', 107],
    ['Valtteri Bottas', 'FIN', 'MERCEDES', 73],
    ['Max Verstappen', 'NED', 'RED BULL RACING HONDA', 77],
    ['Sergio Perez', 'MEX', 'RACING POINT BWT MERCEDES', 22],
    ['Daniel Ricciardo', 'AUS', 'RENAULT', 20],
    ['Carlos Sainz', 'ESP', 'MCLAREN RENAULT', 15],
    ['Alexander Albon', 'THA', 'RED BULL RACING HONDA', 36],
    ['Charles Leclerc', 'MON', 'FERRARI', 45],
    ['Lando Norris', 'GBR', 'MCLAREN RENAULT', 38],
    ['Pierre Gasly', 'FRA', 'ALPHATAURI HONDA', 12],
    ['Lance Stroll', 'CAN', 'RACING POINT BWT MERCEDES', 28],
    ['Esteban Ocon', 'FRA', 'RENAULT', 16],
    ['Sebastian Vettel', 'GER', 'FERRARI', 10],
    ['Daniil Kvyat', 'RUS', 'ALPHATAURI HONDA', 2],
    ['Nico Hulkenberg', 'GER', 'RACING POINT BWT MERCEDES', 6],
    ['Kimi Räikkönen', 'FIN', 'ALFA ROMEO RACING FERRARI', 0],
    ['Antonio Giovinazzi', 'ITA', 'ALFA ROMEO RACING FERRARI', 2],
    ['George Russell', 'GBR', 'WILLIAMS MERCEDES', 0],
    ['Romain Grosjean', 'FRA', 'HAAS FERRARI', 0],
    ['Kevin Magnussen', 'DEN', 'HAAS FERRARI', 1],
    ['Nicholas Latifi', 'CAN', 'WILLIAMS MERCEDES', 0],
    ['Jack Aitken', 'GBR', 'WILLIAMS MERCEDES', 0],
    ['Pietro Fittipaldi', 'BRA', 'HAAS FERRARI', 0]
]

df20 = pd.DataFrame(data20, columns=['Driver', 'Nationality', 'Team', 'Points'])
df20['Year'] = '2020'
df20['Points'] = df20['Points'].astype(float)
df20 = df20.sort_values(by='Points', ascending=False).reset_index(drop=True)

df20
# Out:
#                 Driver Nationality                       Team  Points  Year
# 0       Lewis Hamilton         GBR                   MERCEDES   107.0  2020
# 1       Max Verstappen         NED      RED BULL RACING HONDA    77.0  2020
# 2      Valtteri Bottas         FIN                   MERCEDES    73.0  2020
# 3      Charles Leclerc         MON                    FERRARI    45.0  2020
# 4         Lando Norris         GBR            MCLAREN RENAULT    38.0  2020
# 5      Alexander Albon         THA      RED BULL RACING HONDA    36.0  2020
# 6         Lance Stroll         CAN  RACING POINT BWT MERCEDES    28.0  2020
# 7         Sergio Perez         MEX  RACING POINT BWT MERCEDES    22.0  2020
# 8     Daniel Ricciardo         AUS                    RENAULT    20.0  2020
# 9         Esteban Ocon         FRA                    RENAULT    16.0  2020
# 10        Carlos Sainz         ESP            MCLAREN RENAULT    15.0  2020
# ...

# %%
data21 = [
    ['Max Verstappen', 'NED', 'RED BULL RACING HONDA', 61],
    ['Lewis Hamilton', 'GBR', 'MERCEDES', 69],
    ['Valtteri Bottas', 'FIN', 'MERCEDES', 32],
    ['Sergio Perez', 'MEX', 'RED BULL RACING HONDA', 22],
    ['Carlos Sainz', 'ESP', 'FERRARI', 14],
    ['Lando Norris', 'GBR', 'MCLAREN MERCEDES', 37],
    ['Charles Leclerc', 'MON', 'FERRARI', 28],
    ['Daniel Ricciardo', 'AUS', 'MCLAREN MERCEDES', 16],
    ['Pierre Gasly', 'FRA', 'ALPHATAURI HONDA', 7],
    ['Fernando Alonso', 'ESP', 'ALPINE RENAULT', 5],
    ['Esteban Ocon', 'FRA', 'ALPINE RENAULT', 8],
    ['Sebastian Vettel', 'GER', 'ASTON MARTIN MERCEDES', 0],
    ['Lance Stroll', 'CAN', 'ASTON MARTIN MERCEDES', 5],
    ['Yuki Tsunoda', 'JPN', 'ALPHATAURI HONDA', 2],
    ['George Russell', 'GBR', 'WILLIAMS MERCEDES', 0],
    ['Kimi Räikkönen', 'FIN', 'ALFA ROMEO RACING FERRARI', 0],
    ['Nicholas Latifi', 'CAN', 'WILLIAMS MERCEDES', 0],
    ['Antonio Giovinazzi', 'ITA', 'ALFA ROMEO RACING FERRARI', 0],
    ['Mick Schumacher', 'GER', 'HAAS FERRARI', 0],
    ['Robert Kubica', 'POL', 'ALFA ROMEO RACING FERRARI', 0],
    ['Nikita Mazepin', 'RAF', 'HAAS FERRARI', 0]
]

df21 = pd.DataFrame(data21, columns=['Driver', 'Nationality', 'Team', 'Points'])
df21['Year'] = '2021'
df21 = df21[['Driver', 'Nationality', 'Team', 'Points', 'Year']]
df21 = df21.sort_values(by='Points', ascending=False).reset_index(drop=True)

df21
# Out:
#                 Driver Nationality                       Team  Points  Year
# 0       Lewis Hamilton         GBR                   MERCEDES      69  2021
# 1       Max Verstappen         NED      RED BULL RACING HONDA      61  2021
# 2         Lando Norris         GBR           MCLAREN MERCEDES      37  2021
# 3      Valtteri Bottas         FIN                   MERCEDES      32  2021
# 4      Charles Leclerc         MON                    FERRARI      28  2021
# 5         Sergio Perez         MEX      RED BULL RACING HONDA      22  2021
# 6     Daniel Ricciardo         AUS           MCLAREN MERCEDES      16  2021
# 7         Carlos Sainz         ESP                    FERRARI      14  2021
# 8         Esteban Ocon         FRA             ALPINE RENAULT       8  2021
# 9         Pierre Gasly         FRA           ALPHATAURI HONDA       7  2021
# 10     Fernando Alonso         ESP             ALPINE RENAULT       5  2021
# ...

# %%
data22 = [
    ['Max Verstappen', 'NED', 'RED BULL RACING RBPT', 85],
    ['Charles Leclerc', 'MON', 'FERRARI', 104],
    ['Sergio Perez', 'MEX', 'RED BULL RACING RBPT', 66],
    ['George Russell', 'GBR', 'MERCEDES', 59],
    ['Carlos Sainz', 'ESP', 'FERRARI', 53],
    ['Lewis Hamilton', 'GBR', 'MERCEDES', 36],
    ['Lando Norris', 'GBR', 'MCLAREN MERCEDES', 35],
    ['Esteban Ocon', 'FRA', 'ALPINE RENAULT', 24],
    ['Fernando Alonso', 'ESP', 'ALPINE RENAULT', 2],
    ['Valtteri Bottas', 'FIN', 'ALFA ROMEO FERRARI', 30],
    ['Daniel Ricciardo', 'AUS', 'MCLAREN MERCEDES', 11],
    ['Sebastian Vettel', 'GER', 'ASTON MARTIN ARAMCO MERCEDES', 4],
    ['Kevin Magnussen', 'DEN', 'HAAS FERRARI', 15],
    ['Pierre Gasly', 'FRA', 'ALPHATAURI RBPT', 6],
    ['Lance Stroll', 'CAN', 'ASTON MARTIN ARAMCO MERCEDES', 2],
    ['Mick Schumacher', 'GER', 'HAAS FERRARI', 0],
    ['Yuki Tsunoda', 'JPN', 'ALPHATAURI RBPT', 10],
    ['Zhou Guanyu', 'CHN', 'ALFA ROMEO FERRARI', 1],
    ['Alexander Albon', 'THA', 'WILLIAMS MERCEDES', 3],
    ['Nicholas Latifi', 'CAN', 'WILLIAMS MERCEDES', 0],
    ['Nyck De Vries', 'NED', 'WILLIAMS MERCEDES', 0],
    ['Nico Hulkenberg', 'GER', 'ASTON MARTIN ARAMCO MERCEDES', 0]
]

df22 = pd.DataFrame(data22, columns=['Driver', 'Nationality', 'Team', 'Points'])
df22['Year'] = '2022'
df22['Points'] = df22['Points'].astype(float)
df22 = df22.sort_values(by='Points', ascending=False).reset_index(drop=True)

df22
# Out:
#               Driver Nationality                          Team  Points  Year
# 0    Charles Leclerc         MON                       FERRARI   104.0  2022
# 1     Max Verstappen         NED          RED BULL RACING RBPT    85.0  2022
# 2       Sergio Perez         MEX          RED BULL RACING RBPT    66.0  2022
# 3     George Russell         GBR                      MERCEDES    59.0  2022
# 4       Carlos Sainz         ESP                       FERRARI    53.0  2022
# 5     Lewis Hamilton         GBR                      MERCEDES    36.0  2022
# 6       Lando Norris         GBR              MCLAREN MERCEDES    35.0  2022
# 7    Valtteri Bottas         FIN            ALFA ROMEO FERRARI    30.0  2022
# 8       Esteban Ocon         FRA                ALPINE RENAULT    24.0  2022
# 9    Kevin Magnussen         DEN                  HAAS FERRARI    15.0  2022
# 10  Daniel Ricciardo         AUS              MCLAREN MERCEDES    11.0  2022
# ...

# %%
data23 = [
    ['Max Verstappen', 'NED', 'RED BULL RACING HONDA RBPT', 144],
    ['Sergio Perez', 'MEX', 'RED BULL RACING HONDA RBPT', 105],
    ['Fernando Alonso', 'ESP', 'ASTON MARTIN ARAMCO MERCEDES', 93],
    ['Lewis Hamilton', 'GBR', 'MERCEDES', 69],
    ['George Russell', 'GBR', 'MERCEDES', 50],
    ['Carlos Sainz', 'ESP', 'FERRARI', 48],
    ['Charles Leclerc', 'MON', 'FERRARI', 42],
    ['Lance Stroll', 'CAN', 'ASTON MARTIN ARAMCO MERCEDES', 27],
    ['Esteban Ocon', 'FRA', 'ALPINE RENAULT', 21],
    ['Pierre Gasly', 'FRA', 'ALPINE RENAULT', 14],
    ['Lando Norris', 'GBR', 'MCLAREN MERCEDES', 12],
    ['Nico Hulkenberg', 'GER', 'HAAS FERRARI', 6],
    ['Oscar Piastri', 'AUS', 'MCLAREN MERCEDES', 5],
    ['Valtteri Bottas', 'FIN', 'ALFA ROMEO FERRARI', 4],
    ['Zhou Guanyu', 'CHN', 'ALFA ROMEO FERRARI', 2],
    ['Yuki Tsunoda', 'JPN', 'ALPHATAURI HONDA RBPT', 2],
    ['Kevin Magnussen', 'DEN', 'HAAS FERRARI', 2],
    ['Alexander Albon', 'THA', 'WILLIAMS MERCEDES', 1],
    ['Nyck De Vries', 'NED', 'ALPHATAURI HONDA RBPT', 0],
    ['Logan Sargeant', 'USA', 'WILLIAMS MERCEDES', 0]
]

df23 = pd.DataFrame(data23, columns=['Driver', 'Nationality', 'Team', 'Points'])
df23['Year'] = '2023'
df23['Points'] = df23['Points'].astype(float)
df23 = df23.sort_values(by='Points', ascending=False).reset_index(drop=True)

df23
# Out:
#              Driver Nationality                          Team  Points  Year
# 0    Max Verstappen         NED    RED BULL RACING HONDA RBPT   144.0  2023
# 1      Sergio Perez         MEX    RED BULL RACING HONDA RBPT   105.0  2023
# 2   Fernando Alonso         ESP  ASTON MARTIN ARAMCO MERCEDES    93.0  2023
# 3    Lewis Hamilton         GBR                      MERCEDES    69.0  2023
# 4    George Russell         GBR                      MERCEDES    50.0  2023
# 5      Carlos Sainz         ESP                       FERRARI    48.0  2023
# 6   Charles Leclerc         MON                       FERRARI    42.0  2023
# 7      Lance Stroll         CAN  ASTON MARTIN ARAMCO MERCEDES    27.0  2023
# 8      Esteban Ocon         FRA                ALPINE RENAULT    21.0  2023
# 9      Pierre Gasly         FRA                ALPINE RENAULT    14.0  2023
# 10     Lando Norris         GBR              MCLAREN MERCEDES    12.0  2023
# ...
