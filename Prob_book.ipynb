# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from timple.timedelta import strftimedelta

import fastf1 as f1
import fastf1.plotting
from fastf1.core import Laps

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
schedule2022 = f1.get_event_schedule(2022)
schedule2022[schedule2022['EventName'] == 'Spanish Grand Prix']
# Out:
# req         WARNING
#
# DEFAULT CACHE ENABLED!
# 	Cache directory: C:\Users\usuario\AppData\Local\Temp\fastf1.
# 	Size: 656.2 MB
#    RoundNumber Country   Location
# 7            6   Spain  Barcelona  \
#
#                               OfficialEventName  EventDate
# 7  FORMULA 1 PIRELLI GRAN PREMIO DE ESPAÑA 2022 2022-05-22  \
#
#             EventName   EventFormat    Session1               Session1Date
# 7  Spanish Grand Prix  conventional  Practice 1  2022-05-20 14:00:00+02:00  \
#
#       Session1DateUtc    Session2               Session2Date
# 7 2022-05-20 12:00:00  Practice 2  2022-05-20 17:00:00+02:00  \
#
#       Session2DateUtc    Session3               Session3Date
# 7 2022-05-20 15:00:00  Practice 3  2022-05-21 13:00:00+02:00  \
#
#       Session3DateUtc    Session4               Session4Date
# 7 2022-05-21 11:00:00  Qualifying  2022-05-21 16:00:00+02:00  \
#
#       Session4DateUtc Session5               Session5Date     Session5DateUtc
# ...

# %%
schedule2021 = f1.get_event_schedule(2021)
schedule2021[schedule2021['EventName'] == 'Spanish Grand Prix']
# Out:
#    RoundNumber Country   Location
# 4            4   Spain  Barcelona  \
#
#                              OfficialEventName  EventDate           EventName
# 4  FORMULA 1 ARAMCO GRAN PREMIO DE ESPAÑA 2021 2021-05-09  Spanish Grand Prix  \
#
#     EventFormat    Session1               Session1Date     Session1DateUtc
# 4  conventional  Practice 1  2021-05-07 11:30:00+02:00 2021-05-07 09:30:00  \
#
#      Session2               Session2Date     Session2DateUtc    Session3
# 4  Practice 2  2021-05-07 15:00:00+02:00 2021-05-07 13:00:00  Practice 3  \
#
#                 Session3Date     Session3DateUtc    Session4
# 4  2021-05-08 12:00:00+02:00 2021-05-08 10:00:00  Qualifying  \
#
#                 Session4Date     Session4DateUtc Session5
# 4  2021-05-08 15:00:00+02:00 2021-05-08 13:00:00     Race  \
#
#                 Session5Date     Session5DateUtc  F1ApiSupport
# 4  2021-05-09 15:00:00+02:00 2021-05-09 13:00:00          True

# %%
schedule2020 = f1.get_event_schedule(2020)
schedule2020[schedule2020['EventName'] == 'Spanish Grand Prix']
# Out:
#    RoundNumber Country   Location
# 7            6   Spain  Barcelona  \
#
#                              OfficialEventName  EventDate           EventName
# 7  FORMULA 1 ARAMCO GRAN PREMIO DE ESPAÑA 2020 2020-08-16  Spanish Grand Prix  \
#
#     EventFormat    Session1               Session1Date     Session1DateUtc
# 7  conventional  Practice 1  2020-08-14 11:00:00+02:00 2020-08-14 09:00:00  \
#
#      Session2               Session2Date     Session2DateUtc    Session3
# 7  Practice 2  2020-08-14 15:00:00+02:00 2020-08-14 13:00:00  Practice 3  \
#
#                 Session3Date     Session3DateUtc    Session4
# 7  2020-08-15 12:00:00+02:00 2020-08-15 10:00:00  Qualifying  \
#
#                 Session4Date     Session4DateUtc Session5
# 7  2020-08-15 15:00:00+02:00 2020-08-15 13:00:00     Race  \
#
#                 Session5Date     Session5DateUtc  F1ApiSupport
# 7  2020-08-16 15:10:00+02:00 2020-08-16 13:10:00          True

# %%
schedule2019 = f1.get_event_schedule(2019)
schedule2019[schedule2019['EventName'] == 'Spanish Grand Prix']
# Out:
#    RoundNumber Country   Location
# 4            5   Spain  Barcelona  \
#
#                                OfficialEventName  EventDate
# 4  FORMULA 1 EMIRATES GRAN PREMIO DE ESPAÑA 2019 2019-05-12  \
#
#             EventName   EventFormat    Session1               Session1Date
# 4  Spanish Grand Prix  conventional  Practice 1  2019-05-10 11:00:00+02:00  \
#
#       Session1DateUtc    Session2               Session2Date
# 4 2019-05-10 09:00:00  Practice 2  2019-05-10 15:00:00+02:00  \
#
#       Session2DateUtc    Session3               Session3Date
# 4 2019-05-10 13:00:00  Practice 3  2019-05-11 12:00:00+02:00  \
#
#       Session3DateUtc    Session4               Session4Date
# 4 2019-05-11 10:00:00  Qualifying  2019-05-11 15:00:00+02:00  \
#
#       Session4DateUtc Session5               Session5Date     Session5DateUtc
# 4 2019-05-11 13:00:00     Race  2019-05-12 15:10:00+02:00 2019-05-12 13:10:00  \
#
#    F1ApiSupport
# 4          True

# %%
schedule2018 = f1.get_event_schedule(2018)
schedule2018[schedule2018['EventName'] == 'Spanish Grand Prix']
# Out:
#    RoundNumber Country   Location
# 4            5   Spain  Barcelona  \
#
#                                OfficialEventName  EventDate
# 4  FORMULA 1 GRAN PREMIO DE ESPAÑA EMIRATES 2018 2018-05-13  \
#
#             EventName   EventFormat    Session1               Session1Date
# 4  Spanish Grand Prix  conventional  Practice 1  2018-05-11 11:00:00+02:00  \
#
#       Session1DateUtc    Session2               Session2Date
# 4 2018-05-11 09:00:00  Practice 2  2018-05-11 15:00:00+02:00  \
#
#       Session2DateUtc    Session3               Session3Date
# 4 2018-05-11 13:00:00  Practice 3  2018-05-12 12:00:00+02:00  \
#
#       Session3DateUtc    Session4               Session4Date
# 4 2018-05-12 10:00:00  Qualifying  2018-05-12 15:00:00+02:00  \
#
#       Session4DateUtc Session5               Session5Date     Session5DateUtc
# 4 2018-05-12 13:00:00     Race  2018-05-13 15:10:00+02:00 2018-05-13 13:10:00  \
#
#    F1ApiSupport
# 4          True

# %%
session2022 = f1.get_session(2022, 'Spanish Grand Prix', 'R')
session2022.load()
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.3]
# req            INFO 	Using cached data for driver_info
# logger      WARNING 	Failed to load result data from Ergast!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
session2022.event
# Out:
# RoundNumber                                                     6
# Country                                                     Spain
# Location                                                Barcelona
# OfficialEventName    FORMULA 1 PIRELLI GRAN PREMIO DE ESPAÑA 2022
# EventDate                                     2022-05-22 00:00:00
# EventName                                      Spanish Grand Prix
# EventFormat                                          conventional
# Session1                                               Practice 1
# Session1Date                            2022-05-20 14:00:00+02:00
# Session1DateUtc                               2022-05-20 12:00:00
# Session2                                               Practice 2
# Session2Date                            2022-05-20 17:00:00+02:00
# Session2DateUtc                               2022-05-20 15:00:00
# Session3                                               Practice 3
# ...

# %%
session2021 = f1.get_session(2021, 'Spanish Grand Prix', 'R')
session2021.load()
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.3]
# req            INFO 	Using cached data for driver_info
# logger      WARNING 	Failed to load result data from Ergast!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
session2021.event
# Out:
# RoundNumber                                                    4
# Country                                                    Spain
# Location                                               Barcelona
# OfficialEventName    FORMULA 1 ARAMCO GRAN PREMIO DE ESPAÑA 2021
# EventDate                                    2021-05-09 00:00:00
# EventName                                     Spanish Grand Prix
# EventFormat                                         conventional
# Session1                                              Practice 1
# Session1Date                           2021-05-07 11:30:00+02:00
# Session1DateUtc                              2021-05-07 09:30:00
# Session2                                              Practice 2
# Session2Date                           2021-05-07 15:00:00+02:00
# Session2DateUtc                              2021-05-07 13:00:00
# Session3                                              Practice 3
# ...

# %%
session2020 = f1.get_session(2020, 'Spanish Grand Prix', 'R')
session2020.load()
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.3]
# req            INFO 	Using cached data for driver_info
# logger      WARNING 	Failed to load result data from Ergast!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
session2020.event
# Out:
# RoundNumber                                                    6
# Country                                                    Spain
# Location                                               Barcelona
# OfficialEventName    FORMULA 1 ARAMCO GRAN PREMIO DE ESPAÑA 2020
# EventDate                                    2020-08-16 00:00:00
# EventName                                     Spanish Grand Prix
# EventFormat                                         conventional
# Session1                                              Practice 1
# Session1Date                           2020-08-14 11:00:00+02:00
# Session1DateUtc                              2020-08-14 09:00:00
# Session2                                              Practice 2
# Session2Date                           2020-08-14 15:00:00+02:00
# Session2DateUtc                              2020-08-14 13:00:00
# Session3                                              Practice 3
# ...

# %%
session2019 = f1.get_session(2019, 'Spanish Grand Prix', 'R')
session2019.load()
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.3]
# req            INFO 	Using cached data for driver_info
# logger      WARNING 	Failed to load result data from Ergast!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
session2019.event
# Out:
# RoundNumber                                                      5
# Country                                                      Spain
# Location                                                 Barcelona
# OfficialEventName    FORMULA 1 EMIRATES GRAN PREMIO DE ESPAÑA 2019
# EventDate                                      2019-05-12 00:00:00
# EventName                                       Spanish Grand Prix
# EventFormat                                           conventional
# Session1                                                Practice 1
# Session1Date                             2019-05-10 11:00:00+02:00
# Session1DateUtc                                2019-05-10 09:00:00
# Session2                                                Practice 2
# Session2Date                             2019-05-10 15:00:00+02:00
# Session2DateUtc                                2019-05-10 13:00:00
# Session3                                                Practice 3
# ...

# %%
session2018 = f1.get_session(2018, 'Spanish Grand Prix', 'R')
session2018.load()
# Out:
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.3]
# req            INFO 	Using cached data for driver_info
# logger      WARNING 	Failed to load result data from Ergast!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
session2018.event
# Out:
# RoundNumber                                                      5
# Country                                                      Spain
# Location                                                 Barcelona
# OfficialEventName    FORMULA 1 GRAN PREMIO DE ESPAÑA EMIRATES 2018
# EventDate                                      2018-05-13 00:00:00
# EventName                                       Spanish Grand Prix
# EventFormat                                           conventional
# Session1                                                Practice 1
# Session1Date                             2018-05-11 11:00:00+02:00
# Session1DateUtc                                2018-05-11 09:00:00
# Session2                                                Practice 2
# Session2Date                             2018-05-11 15:00:00+02:00
# Session2DateUtc                                2018-05-11 13:00:00
# Session3                                                Practice 3
# ...

# %%
session2022.car_data['16']
# Out:
#                          Date  RPM  Speed  nGear  Throttle  Brake  DRS Source
# 0     2022-05-22 12:02:34.720    0      0      0         0  False    0    car  \
# 1     2022-05-22 12:02:35.080    0      0      0         0  False    0    car
# 2     2022-05-22 12:02:35.280    0      0      0         0  False    0    car
# 3     2022-05-22 12:02:35.560    0      0      0         0  False    0    car
# 4     2022-05-22 12:02:35.999    0      0      0         0  False    0    car
# ...                       ...  ...    ...    ...       ...    ...  ...    ...
# 36473 2022-05-22 14:44:57.667    0      0      0       104   True    0    car
# 36474 2022-05-22 14:44:57.867    0      0      0       104   True    0    car
# 36475 2022-05-22 14:44:58.028    0      0      0       104   True    0    car
# 36476 2022-05-22 14:44:58.308    0      0      0       104   True    0    car
# 36477 2022-05-22 14:44:58.548    0      0      0       104   True    0    car
#
# ...

# %%
session2022.car_data['1']
# Out:
#                          Date  RPM  Speed  nGear  Throttle  Brake  DRS Source
# 0     2022-05-22 12:02:34.720    0      0      0         0  False    0    car  \
# 1     2022-05-22 12:02:35.080    0      0      0         0  False    0    car
# 2     2022-05-22 12:02:35.280    0      0      0         0  False    0    car
# 3     2022-05-22 12:02:35.560    0      0      0         0  False    0    car
# 4     2022-05-22 12:02:35.999    0      0      0         0  False    0    car
# ...                       ...  ...    ...    ...       ...    ...  ...    ...
# 36473 2022-05-22 14:44:57.667    0      0      0         0  False    0    car
# 36474 2022-05-22 14:44:57.867    0      0      0         0  False    0    car
# 36475 2022-05-22 14:44:58.028    0      0      0         0  False    0    car
# 36476 2022-05-22 14:44:58.308    0      0      0         0  False    0    car
# 36477 2022-05-22 14:44:58.548    0      0      0         0  False    0    car
#
# ...

# %%
session2022.laps
# Out:
#                        Time Driver DriverNumber                LapTime
# 0    0 days 01:03:41.958000    LEC           16                    NaT  \
# 1    0 days 01:05:09.585000    LEC           16 0 days 00:01:27.627000
# 2    0 days 01:06:36.783000    LEC           16 0 days 00:01:27.198000
# 3    0 days 01:08:04.454000    LEC           16 0 days 00:01:27.671000
# 4    0 days 01:09:32.345000    LEC           16 0 days 00:01:27.891000
# ...                     ...    ...          ...                    ...
# 1225 0 days 02:33:48.631000    ALO           14 0 days 00:01:27.384000
# 1226 0 days 02:35:16.350000    ALO           14 0 days 00:01:27.719000
# 1227 0 days 02:36:43.771000    ALO           14 0 days 00:01:27.421000
# 1228 0 days 02:38:12.264000    ALO           14 0 days 00:01:28.493000
# 1229 0 days 02:39:40.534000    ALO           14 0 days 00:01:28.270000
#
#       LapNumber  Stint             PitOutTime PitInTime
# 0           1.0    1.0 0 days 00:23:48.142000       NaT  \
# ...

# %%
session2022.pos_data['16']
# Out:
#                          Date   Status    X     Y     Z Source
# 0     2022-05-22 12:02:51.374  OnTrack    0     0     0    pos  \
# 1     2022-05-22 12:02:51.754  OnTrack    0     0     0    pos
# 2     2022-05-22 12:02:52.014  OnTrack    0     0     0    pos
# 3     2022-05-22 12:02:52.094  OnTrack    0     0     0    pos
# 4     2022-05-22 12:02:52.354  OnTrack    0     0     0    pos
# ...                       ...      ...  ...   ...   ...    ...
# 37925 2022-05-22 14:44:57.374  OnTrack  284 -1043  1744    pos
# 37926 2022-05-22 14:44:57.654  OnTrack  284 -1043  1744    pos
# 37927 2022-05-22 14:44:57.913  OnTrack  284 -1043  1744    pos
# 37928 2022-05-22 14:44:58.073  OnTrack  284 -1043  1744    pos
# 37929 2022-05-22 14:44:58.373  OnTrack  284 -1043  1744    pos
#
#                         Time            SessionTime
# 0     0 days 00:01:51.361000 0 days 00:01:51.361000
# 1     0 days 00:01:51.741000 0 days 00:01:51.741000
# ...

# %%
session2022.pos_data['1']
# Out:
#                          Date   Status    X    Y     Z Source
# 0     2022-05-22 12:02:51.374  OnTrack    0    0     0    pos  \
# 1     2022-05-22 12:02:51.754  OnTrack    0    0     0    pos
# 2     2022-05-22 12:02:52.014  OnTrack    0    0     0    pos
# 3     2022-05-22 12:02:52.094  OnTrack    0    0     0    pos
# 4     2022-05-22 12:02:52.354  OnTrack    0    0     0    pos
# ...                       ...      ...  ...  ...   ...    ...
# 37925 2022-05-22 14:44:57.374  OnTrack  868 -138  1744    pos
# 37926 2022-05-22 14:44:57.654  OnTrack  868 -138  1744    pos
# 37927 2022-05-22 14:44:57.913  OnTrack  868 -138  1744    pos
# 37928 2022-05-22 14:44:58.073  OnTrack  868 -138  1744    pos
# 37929 2022-05-22 14:44:58.373  OnTrack  868 -138  1744    pos
#
#                         Time            SessionTime
# 0     0 days 00:01:51.361000 0 days 00:01:51.361000
# 1     0 days 00:01:51.741000 0 days 00:01:51.741000
# 2     0 days 00:01:52.001000 0 days 00:01:52.001000
# ...

# %%
session2022.race_control_messages
# Out:
#                    Time Category
# 0   2022-05-22 12:05:23    Other  \
# 1   2022-05-22 12:08:30    Other
# 2   2022-05-22 12:11:41    Other
# 3   2022-05-22 12:20:01     Flag
# 4   2022-05-22 12:30:01    Other
# ..                  ...      ...
# 106 2022-05-22 14:41:14    Other
# 107 2022-05-22 14:55:13     Flag
# 108 2022-05-22 14:55:16     Flag
# 109 2022-05-22 14:55:19     Flag
# 110 2022-05-22 14:55:22     Flag
#
#                                                Message Status           Flag
# 0                               DRS DISABLED IN ZONE 2   None           None  \
# 1                                DRS ENABLED IN ZONE 2   None           None
# 2              BLUE HEAD PADDING MATERIAL MUST BE USED   None           None
# 3                          GREEN LIGHT - PIT EXIT OPEN   None          GREEN
# 4                                      PIT EXIT CLOSED   None           None
# ..                                                 ...    ...            ...
# ...

# %%
session2022.results.head()
# Out:
#    DriverNumber BroadcastName Abbreviation DriverId         TeamName
# 16           16     C LECLERC          LEC                   Ferrari  \
# 1             1  M VERSTAPPEN          VER           Red Bull Racing
# 55           55       C SAINZ          SAI                   Ferrari
# 63           63     G RUSSELL          RUS                  Mercedes
# 11           11       S PEREZ          PER           Red Bull Racing
#
#    TeamColor TeamId FirstName    LastName         FullName
# 16    ed1c24          Charles     Leclerc  Charles Leclerc  \
# 1     1e5bc6              Max  Verstappen   Max Verstappen
# 55    ed1c24           Carlos       Sainz     Carlos Sainz
# 63    6cd3bf           George     Russell   George Russell
# 11    1e5bc6           Sergio       Perez     Sergio Perez
#
#                                           HeadshotUrl CountryCode  Position
# 16  https://www.formula1.com/content/dam/fom-websi...         MON       NaN  \
# ...

# %%
session2022.track_status
# Out:
#                     Time Status   Message
# 0        0 days 00:00:00      2    Yellow
# 1 0 days 00:07:30.185000      1  AllClear
# 2 0 days 01:02:47.426000      2    Yellow
# 3 0 days 01:02:59.996000      1  AllClear
# 4 0 days 01:11:36.002000      2    Yellow
# 5 0 days 01:11:48.338000      1  AllClear
# 6 0 days 01:14:25.457000      2    Yellow
# 7 0 days 01:14:33.638000      1  AllClear

# %%
session2022.weather_data
# Out:
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp
# 0   0 days 00:00:13.023000     36.3       8.0     996.9     False       48.3  \
# 1   0 days 00:01:13.014000     36.2       8.0     996.9     False       48.4
# 2   0 days 00:02:13.011000     36.1       8.0     996.7     False       48.6
# 3   0 days 00:03:13.038000     36.1       7.0     996.7     False       48.8
# 4   0 days 00:04:13.041000     36.1       7.0     996.7     False       48.8
# ..                     ...      ...       ...       ...       ...        ...
# 159 0 days 02:39:13.439000     36.4       7.0     995.2     False       48.1
# 160 0 days 02:40:13.438000     36.4       8.0     995.2     False       47.8
# 161 0 days 02:41:13.440000     36.6       8.0     995.2     False       47.8
# 162 0 days 02:42:13.432000     36.7       9.0     995.2     False       47.9
# 163 0 days 02:43:13.464000     36.7      11.0     995.2     False       47.6
#
#      WindDirection  WindSpeed
# ...

# %%
session2021.weather_data
# Out:
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp
# 0   0 days 00:00:31.507000     22.3      55.0     994.5     False       34.1  \
# 1   0 days 00:01:31.508000     22.1      55.9     994.8     False       33.6
# 2   0 days 00:02:31.507000     22.1      56.9     995.0     False       33.3
# 3   0 days 00:03:31.505000     21.9      57.2     995.1     False       32.9
# 4   0 days 00:04:31.511000     21.9      57.4     995.2     False       32.8
# ..                     ...      ...       ...       ...       ...        ...
# 125 0 days 02:05:32.131000     23.2      56.2     991.6     False       35.9
# 126 0 days 02:06:32.133000     23.3      56.6     991.6     False       35.6
# 127 0 days 02:07:32.131000     23.3      56.2     991.5     False       35.4
# 128 0 days 02:08:32.129000     23.5      56.2     991.6     False       35.5
# 129 0 days 02:09:32.134000     23.5      55.2     991.5     False       35.5
#
#      WindDirection  WindSpeed
# ...

# %%
session2020.weather_data
# Out:
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp
# 0   0 days 00:00:51.801000     28.8      58.3     998.0     False       43.9  \
# 1   0 days 00:01:51.801000     28.8      57.7     997.9     False       44.1
# 2   0 days 00:02:51.802000     28.9      57.8     998.0     False       45.5
# 3   0 days 00:03:51.806000     29.0      57.0     997.9     False       45.6
# 4   0 days 00:04:51.809000     29.0      57.5     998.0     False       46.8
# ..                     ...      ...       ...       ...       ...        ...
# 124 0 days 02:04:52.162000     29.7      57.9     997.6     False       46.2
# 125 0 days 02:05:52.162000     29.6      58.3     997.6     False       46.4
# 126 0 days 02:06:52.164000     29.6      58.3     997.6     False       46.2
# 127 0 days 02:07:52.163000     29.7      58.0     997.6     False       47.1
# 128 0 days 02:08:52.166000     29.9      56.8     997.6     False       47.1
#
#      WindDirection  WindSpeed
# ...

# %%
session2019.weather_data
# Out:
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp
# 0   0 days 00:00:14.225000     20.4      55.1    1007.1     False       42.0  \
# 1   0 days 00:01:14.242000     20.5      55.8    1007.1     False       42.4
# 2   0 days 00:02:14.248000     20.5      54.8    1007.2     False       42.4
# 3   0 days 00:03:14.261000     20.4      54.8    1007.1     False       42.1
# 4   0 days 00:04:14.276000     20.4      55.4    1007.1     False       42.1
# ..                     ...      ...       ...       ...       ...        ...
# 127 0 days 02:07:15.984000     20.4      50.6    1006.5     False       39.0
# 128 0 days 02:08:15.995000     20.1      51.0    1006.5     False       38.9
# 129 0 days 02:09:16.008000     20.0      50.0    1006.4     False       38.8
# 130 0 days 02:10:16.037000     19.9      50.2    1006.5     False       38.7
# 131 0 days 02:11:16.181000     19.8      50.8    1006.5     False       38.7
#
#      WindDirection  WindSpeed
# ...

# %%
session2018.weather_data
# Out:
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp
# 0   0 days 00:00:33.475000     15.1      55.7    1001.8     False       35.0  \
# 1   0 days 00:01:33.488000     15.4      55.1    1001.7     False       35.0
# 2   0 days 00:02:33.503000     15.3      54.4    1001.6     False       35.0
# 3   0 days 00:03:33.517000     15.1      54.6    1001.8     False       35.0
# 4   0 days 00:04:33.531000     15.1      54.4    1001.7      True       35.0
# ..                     ...      ...       ...       ...       ...        ...
# 100 0 days 01:40:34.846000     16.9      49.5    1001.5     False       30.7
# 101 0 days 01:41:34.857000     16.9      49.5    1001.5     False       30.7
# 102 0 days 01:42:34.871000     16.5      51.2    1001.6     False       29.8
# 103 0 days 01:43:34.887000     16.0      52.4    1001.7     False       29.1
# 104 0 days 01:44:34.902000     16.0      53.2    1001.6      True       29.3
#
#      WindDirection  WindSpeed
# ...
