# %%
import pandas as pd
import numpy as np

# %%
circuits = pd.read_csv('Dataframes/circuits.csv')
constructors = pd.read_csv('Dataframes/constructors.csv')
drivers = pd.read_csv('Dataframes/drivers.csv')
races = pd.read_csv('Dataframes/races.csv')
lap_times = pd.read_csv('Dataframes/lap_times.csv')
results = pd.read_csv('Dataframes/results.csv')

# %%
circuits.shape
# Out:
# (77, 9)

# %%
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne  \
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt
# 0  Australia -37.84970  144.96800   10  \
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ...

# %%
circuits['name'].unique()
# Out:
# array(['Albert Park Grand Prix Circuit', 'Sepang International Circuit',
#        'Bahrain International Circuit', 'Circuit de Barcelona-Catalunya',
#        'Istanbul Park', 'Circuit de Monaco', 'Circuit Gilles Villeneuve',
#        'Circuit de Nevers Magny-Cours', 'Silverstone Circuit',
#        'Hockenheimring', 'Hungaroring', 'Valencia Street Circuit',
#        'Circuit de Spa-Francorchamps', 'Autodromo Nazionale di Monza',
#        'Marina Bay Street Circuit', 'Fuji Speedway',
#        'Shanghai International Circuit', 'Autódromo José Carlos Pace',
#        'Indianapolis Motor Speedway', 'Nürburgring',
#        'Autodromo Enzo e Dino Ferrari', 'Suzuka Circuit',
#        'Las Vegas Strip Street Circuit', 'Yas Marina Circuit',
#        'Autódromo Juan y Oscar Gálvez', 'Circuito de Jerez',
#        'Autódromo do Estoril', 'Okayama International Circuit',
#        'Adelaide Street Circuit', 'Kyalami', 'Donington Park',
# ...

# %%
circuit_es = circuits[circuits['name'] == 'Circuit de Barcelona-Catalunya']
circuit_es = circuit_es.sort_values(by='circuitId', ascending=False)

circuit_es
# Out:
#    circuitId circuitRef                            name  location country
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
#
#      lat      lng  alt                                                url
# 3  41.57  2.26111  109  http://en.wikipedia.org/wiki/Circuit_de_Barcel...

# %%
races.shape
# Out:
# (1102, 18)

# %%
races.head()
# Out:
#    raceId  year  round  circuitId                   name        date
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29  \
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N  \
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time
# ...

# %%
races['name'].value_counts().head(10)
# Out:
# name
# Italian Grand Prix          74
# British Grand Prix          74
# Monaco Grand Prix           69
# Belgian Grand Prix          68
# German Grand Prix           64
# French Grand Prix           62
# Spanish Grand Prix          53
# Canadian Grand Prix         52
# Brazilian Grand Prix        48
# United States Grand Prix    44
# Name: count, dtype: int64

# %%
races_es = races[(races['name'] == 'Spanish Grand Prix') & (races['year'].between(1996, 2022))]
races_es = races_es.drop(['fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time', 'quali_date', 'quali_time', 'sprint_date', 'sprint_time'], axis=1)
races_es = races_es.sort_values(by='raceId', ascending=False)

races_es
# Out:
#       raceId  year  round  circuitId                name        date
# 1062    1079  2022      6          4  Spanish Grand Prix  2022-05-22  \
# 1040    1055  2021      4          4  Spanish Grand Prix  2021-05-09
# 1023    1036  2020      6          4  Spanish Grand Prix  2020-08-16
# 1001    1014  2019      5          4  Spanish Grand Prix  2019-05-12
# 980      993  2018      5          4  Spanish Grand Prix  2018-05-13
# 960      973  2017      5          4  Spanish Grand Prix  2017-05-14
# 939      952  2016      5          4  Spanish Grand Prix  2016-05-15
# 919      930  2015      5          4  Spanish Grand Prix  2015-05-10
# 901      904  2014      5          4  Spanish Grand Prix  2014-05-11
# 882      884  2013      5          4  Spanish Grand Prix  2013-05-12
# 862      864  2012      5          4  Spanish Grand Prix  2012-05-13
# 843      845  2011      5          4  Spanish Grand Prix  2011-05-22
# 340      341  2010      5          4  Spanish Grand Prix  2010-05-09
# ...

# %%
lap_times.head()
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342

# %%
lap_times_es = lap_times[lap_times['raceId'].isin(races_es['raceId'])]
lap_times_es = lap_times_es.sort_values(by='raceId', ascending=False)

lap_times_es
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 520988    1079       825   64        17  1:33.091         93091
# 520171    1079       822   57         4  1:28.149         88149
# 520164    1079       822   50         4  1:28.275         88275
# 520165    1079       822   51         4  1:28.130         88130
# 520166    1079       822   52         3  1:28.684         88684
# ...        ...       ...  ...       ...       ...           ...
# 346905       5         4   32         6  1:24.165         84165
# 346906       5         4   33         6  1:24.250         84250
# 346907       5         4   34         6  1:24.031         84031
# 346908       5         4   35         6  1:23.942         83942
# 346809       5         2    2         9  2:25.148        145148
#
# [30994 rows x 6 columns]

# %%
len(lap_times_es['raceId'].unique()) == len(races_es['raceId'].unique())
# Out:
# True

# %%
drivers.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07  \
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
drivers_es = drivers[drivers['driverId'].isin(lap_times_es['driverId'])]
drivers_es = drivers_es.sort_values(by='driverId', ascending=False)

drivers_es
# Out:
#      driverId        driverRef number code  forename     surname         dob
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30  \
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 851       853          mazepin      9  MAZ    Nikita     Mazepin  1999-03-02
# 850       852          tsunoda     22  TSU      Yuki     Tsunoda  2000-05-11
# 847       849           latifi      6  LAT  Nicholas      Latifi  1995-06-29
# ..        ...              ...    ...  ...       ...         ...         ...
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
#
# ...

# %%
race2022 = lap_times[lap_times['raceId'] == 1079]

race2022.shape
# Out:
# (1230, 6)

# %%
race2022.head()
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 519759    1079       844    1         1  1:28.746         88746
# 519760    1079       844    2         1  1:27.627         87627
# 519761    1079       844    3         1  1:27.198         87198
# 519762    1079       844    4         1  1:27.671         87671
# 519763    1079       844    5         1  1:27.891         87891

# %%
race2022['lap'].value_counts()
# Out:
# lap
# 1     20
# 15    20
# 2     20
# 27    20
# 26    20
# 25    20
# 23    20
# 22    20
# 21    20
# 20    20
# 19    20
# 18    20
# 17    20
# 16    20
# 24    20
# 14    20
# 7     20
# 3     20
# 13    20
# 4     20
# 6     20
# 5     20
# 8     20
# 9     20
# 10    20
# 11    20
# 12    20
# 28    19
# 49    18
# 56    18
# 50    18
# 51    18
# 52    18
# 53    18
# 54    18
# 55    18
# 62    18
# 57    18
# 58    18
# 59    18
# 60    18
# 61    18
# 63    18
# 64    18
# 47    18
# 48    18
# 34    18
# 46    18
# 45    18
# 29    18
# 30    18
# 31    18
# 32    18
# 33    18
# 35    18
# 36    18
# 37    18
# 38    18
# 39    18
# 40    18
# 41    18
# 42    18
# 43    18
# 44    18
# 65    15
# 66     8
# Name: count, dtype: int64

# %%
race2022_ham = race2022[race2022['driverId'] == 1]

race2022_ham
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 520859    1079         1    1        19  1:55.147        115147
# 520860    1079         1    2        19  1:55.134        115134
# 520861    1079         1    3        19  1:27.495         87495
# 520862    1079         1    4        19  1:28.327         88327
# 520863    1079         1    5        19  1:29.321         89321
# 520864    1079         1    6        19  1:28.986         88986
# 520865    1079         1    7        19  1:29.147         89147
# 520866    1079         1    8        19  1:29.086         89086
# 520867    1079         1    9        19  1:28.606         88606
# 520868    1079         1   10        19  1:28.558         88558
# 520869    1079         1   11        19  1:29.331         89331
# 520870    1079         1   12        18  1:28.746         88746
# 520871    1079         1   13        17  1:29.037         89037
# 520872    1079         1   14        17  1:29.167         89167
# ...

# %%
race2021 = lap_times[lap_times['raceId'] == 1055]

race2021.shape
# Out:
# (1246, 6)

# %%
race2021['lap'].value_counts()
# Out:
# lap
# 1     20
# 3     20
# 4     20
# 5     20
# 6     20
# 2     20
# 43    19
# 48    19
# 47    19
# 46    19
# 45    19
# 44    19
# 40    19
# 42    19
# 41    19
# 50    19
# 39    19
# 38    19
# 49    19
# 53    19
# 51    19
# 52    19
# 36    19
# 54    19
# 55    19
# 56    19
# 57    19
# 58    19
# 59    19
# 60    19
# 61    19
# 62    19
# 63    19
# 64    19
# 37    19
# 34    19
# 35    19
# 33    19
# 7     19
# 8     19
# 9     19
# 10    19
# 11    19
# 12    19
# 13    19
# 14    19
# 15    19
# 16    19
# 17    19
# 18    19
# 19    19
# 20    19
# 21    19
# 22    19
# 23    19
# 24    19
# 25    19
# 26    19
# 27    19
# 28    19
# 29    19
# 30    19
# 31    19
# 32    19
# 65    17
# 66     7
# Name: count, dtype: int64

# %%
race2020 = lap_times[lap_times['raceId'] == 1055]

race2020.shape
# Out:
# (1246, 6)

# %%
constructors.head()
# Out:
#    constructorId constructorRef        name nationality
# 0              1        mclaren     McLaren     British  \
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
results.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position
# 0         1      18         1              1     22     1        1  \
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds
# 0            1              1    10.0    58  1:34:50.616      5690616  \
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
results_es = results[results['raceId'].isin(races_es['raceId'])]
results_es = results_es.sort_values(by='raceId', ascending=False)

results_es
# Out:
#        resultId  raceId  driverId  constructorId number  grid position
# 25519     25525    1079       844              6     16     1       \N  \
# 25509     25515    1079       852            213     22    13       10
# 25500     25506    1079       830              9      1     2        1
# 25502     25508    1079       847            131     63     4        3
# 25503     25509    1079       832              6     55     3        4
# ...         ...     ...       ...            ...    ...   ...      ...
# 7637       7638       5         4              4      7     8        5
# 7636       7637       5        20              9     15     2        4
# 7635       7636       5        17              9     14     5        3
# 7634       7635       5        22             23     23     3        2
# 7643       7644       5         9              2      5    10       11
#
#       positionText  positionOrder  points  laps         time milliseconds
# ...

# %%
constructors_es = constructors[constructors['constructorId'].isin(results_es['constructorId'])]
constructors_es = constructors_es.sort_values(by='constructorId', ascending=False)

constructors_es.head()
# Out:
#      constructorId constructorRef            name nationality
# 210            214         alpine  Alpine F1 Team      French  \
# 209            213     alphatauri      AlphaTauri     Italian
# 208            211   racing_point    Racing Point     British
# 207            210           haas    Haas F1 Team    American
# 206            209          manor  Manor Marussia     British
#
#                                                    url
# 210        http://en.wikipedia.org/wiki/Alpine_F1_Team
# 209   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 208  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 207          http://en.wikipedia.org/wiki/Haas_F1_Team
# 206      http://en.wikipedia.org/wiki/Manor_Motorsport

# %%
circuit_es#.head()
# Out:
#    circuitId circuitRef                            name  location country
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
#
#      lat      lng  alt                                                url
# 3  41.57  2.26111  109  http://en.wikipedia.org/wiki/Circuit_de_Barcel...

# %%
circuit_es.shape
# Out:
# (1, 9)

# %%
constructors_es = constructors_es.drop('url', axis=1)

constructors_es#.head()
# Out:
#      constructorId constructorRef            name nationality
# 210            214         alpine  Alpine F1 Team      French
# 209            213     alphatauri      AlphaTauri     Italian
# 208            211   racing_point    Racing Point     British
# 207            210           haas    Haas F1 Team    American
# 206            209          manor  Manor Marussia     British
# 205            208       lotus_f1        Lotus F1     British
# 204            207       caterham        Caterham   Malaysian
# 203            206       marussia        Marussia     Russian
# 202            205   lotus_racing           Lotus   Malaysian
# 164            166         virgin          Virgin     British
# 162            164            hrt             HRT     Spanish
# 129            131       mercedes        Mercedes      German
# 115            117   aston_martin    Aston Martin     British
# 49              51           alfa      Alfa Romeo       Swiss
# ...

# %%
constructors_es.shape
# Out:
# (41, 4)

# %%
drivers_es['number'].unique()
drivers_es['code'].unique()
# Out:
# array(['ZHO', 'MSC', 'MAZ', 'TSU', 'LAT', 'ALB', 'RUS', 'NOR', 'SIR',
#        'LEC', 'HAR', 'GAS', 'GIO', 'STR', 'OCO', 'VAN', 'WEH', 'PAL',
#        'MER', 'SAI', 'NAS', 'VER', 'STE', 'ERI', 'KVY', 'MAG', 'BIA',
#        'VDG', 'BOT', 'GUT', 'CHI', 'PIC', 'RIC', 'DAM', 'PER', 'DIR',
#        'MAL', 'CHA', 'SEN', 'DIG', 'PET', 'HUL', 'KOB', 'GRO', 'ALG',
#        '\\N', 'BAD', 'BUE', 'ZON', 'FRI', 'KAR', 'DLR', 'FMO', 'VIL',
#        'TMO', 'KLI', 'MON', 'SPE', 'WUR', 'LIU', 'SCH', 'BAR', 'FIS',
#        'VET', 'DAV', 'BUT', 'WEB', 'SUT', 'TRU', 'COU', 'MAS', 'PIQ',
#        'SAT', 'GLO', 'KUB', 'RAI', 'BOU', 'NAK', 'KOV', 'ALO', 'ROS',
#        'HEI', 'HAM'], dtype=object)

# %%
#pd.set_option('display.max_rows', 75)

result = drivers_es.loc[(drivers_es['number'] == r'\N') | (drivers_es['code'] == r'\N')]

result
# Out:
#      driverId           driverRef number code      forename        surname
# 822       823               garde     \N  VDG         Giedo  van der Garde  \
# 818       819                 pic     \N  PIC       Charles            Pic
# 815       816            ambrosio     \N  DAM        Jérôme     d'Ambrosio
# 813       814               resta     \N  DIR          Paul       di Resta
# 811       812            chandhok     \N  CHA         Karun       Chandhok
# 810       811         bruno_senna     \N  SEN         Bruno          Senna
# 809       810              grassi     \N  DIG         Lucas      di Grassi
# 808       808              petrov     \N  PET        Vitaly         Petrov
# 152       153         alguersuari     \N  ALG         Jaime    Alguersuari
# 83         84             brundle     \N   \N        Martin        Brundle
# 80         81          morbidelli     \N   \N        Gianni     Morbidelli
# ...

# %%
drivers_es = drivers_es.drop(['number', 'code', 'url'], axis=1)

drivers_es#.head()
# Out:
#      driverId        driverRef  forename     surname         dob nationality
# 853       855             zhou    Guanyu        Zhou  1999-05-30     Chinese
# 852       854  mick_schumacher      Mick  Schumacher  1999-03-22      German
# 851       853          mazepin    Nikita     Mazepin  1999-03-02     Russian
# 850       852          tsunoda      Yuki     Tsunoda  2000-05-11    Japanese
# 847       849           latifi  Nicholas      Latifi  1995-06-29    Canadian

# %%
drivers_es.shape
# Out:
# (117, 6)

# %%
races_es#.head()
# Out:
#       raceId  year  round  circuitId                name        date
# 1062    1079  2022      6          4  Spanish Grand Prix  2022-05-22  \
# 1040    1055  2021      4          4  Spanish Grand Prix  2021-05-09
# 1023    1036  2020      6          4  Spanish Grand Prix  2020-08-16
# 1001    1014  2019      5          4  Spanish Grand Prix  2019-05-12
# 980      993  2018      5          4  Spanish Grand Prix  2018-05-13
# 960      973  2017      5          4  Spanish Grand Prix  2017-05-14
# 939      952  2016      5          4  Spanish Grand Prix  2016-05-15
# 919      930  2015      5          4  Spanish Grand Prix  2015-05-10
# 901      904  2014      5          4  Spanish Grand Prix  2014-05-11
# 882      884  2013      5          4  Spanish Grand Prix  2013-05-12
# 862      864  2012      5          4  Spanish Grand Prix  2012-05-13
# 843      845  2011      5          4  Spanish Grand Prix  2011-05-22
# 340      341  2010      5          4  Spanish Grand Prix  2010-05-09
# ...

# %%
races_es.shape
# Out:
# (27, 8)

# %%
lap_times_es#.head()
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 520988    1079       825   64        17  1:33.091         93091
# 520171    1079       822   57         4  1:28.149         88149
# 520164    1079       822   50         4  1:28.275         88275
# 520165    1079       822   51         4  1:28.130         88130
# 520166    1079       822   52         3  1:28.684         88684
# ...        ...       ...  ...       ...       ...           ...
# 346905       5         4   32         6  1:24.165         84165
# 346906       5         4   33         6  1:24.250         84250
# 346907       5         4   34         6  1:24.031         84031
# 346908       5         4   35         6  1:23.942         83942
# 346809       5         2    2         9  2:25.148        145148
#
# [30994 rows x 6 columns]

# %%
lap_times_es.shape
# Out:
# (30994, 6)

# %%
lap_times_es['raceId'].unique()
# Out:
# array([1079, 1055, 1036, 1014,  993,  973,  952,  930,  904,  884,  864,
#         845,  341,  230,  212,  195,  179,  162,  145,  128,  112,   94,
#          75,   58,   39,   21,    5], dtype=int64)
