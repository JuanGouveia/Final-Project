# %%
import pandas as pd
import numpy as np

# %%
circuits = pd.read_csv('Dataframes/circuits.csv')
constructors = pd.read_csv('Dataframes/constructors.csv')
drivers = pd.read_csv('Dataframes/drivers.csv')
races = pd.read_csv('Dataframes/races.csv')
lap_times = pd.read_csv('Dataframes/lap_times.csv')
results = pd.read_csv('Dataframes/results.csv')
qualifying = pd.read_csv('Dataframes/qualifying.csv')
d_points = pd.read_csv('Dataframes/driver_points_es.csv')
c_points = pd.read_csv('Dataframes/constructor_points_es.csv')
safety = pd.read_csv('Dataframes/safety_car.csv')

# %%
circuits.shape
# Out:
# (77, 9)

# %%
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne  \
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt
# 0  Australia -37.84970  144.96800   10  \
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ...

# %%
circuits['name'].unique()
# Out:
# array(['Albert Park Grand Prix Circuit', 'Sepang International Circuit',
#        'Bahrain International Circuit', 'Circuit de Barcelona-Catalunya',
#        'Istanbul Park', 'Circuit de Monaco', 'Circuit Gilles Villeneuve',
#        'Circuit de Nevers Magny-Cours', 'Silverstone Circuit',
#        'Hockenheimring', 'Hungaroring', 'Valencia Street Circuit',
#        'Circuit de Spa-Francorchamps', 'Autodromo Nazionale di Monza',
#        'Marina Bay Street Circuit', 'Fuji Speedway',
#        'Shanghai International Circuit', 'Autódromo José Carlos Pace',
#        'Indianapolis Motor Speedway', 'Nürburgring',
#        'Autodromo Enzo e Dino Ferrari', 'Suzuka Circuit',
#        'Las Vegas Strip Street Circuit', 'Yas Marina Circuit',
#        'Autódromo Juan y Oscar Gálvez', 'Circuito de Jerez',
#        'Autódromo do Estoril', 'Okayama International Circuit',
#        'Adelaide Street Circuit', 'Kyalami', 'Donington Park',
# ...

# %%
circuit_es = circuits[circuits['name'] == 'Circuit de Barcelona-Catalunya']
circuit_es = circuit_es.sort_values(by='circuitId', ascending=False)

circuit_es
# Out:
#    circuitId circuitRef                            name  location country
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
#
#      lat      lng  alt                                                url
# 3  41.57  2.26111  109  http://en.wikipedia.org/wiki/Circuit_de_Barcel...

# %%
races.shape
# Out:
# (1102, 18)

# %%
races.head()
# Out:
#    raceId  year  round  circuitId                   name        date
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29  \
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N  \
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time
# ...

# %%
races['name'].value_counts().head(10)
# Out:
# name
# Italian Grand Prix          74
# British Grand Prix          74
# Monaco Grand Prix           69
# Belgian Grand Prix          68
# German Grand Prix           64
# French Grand Prix           62
# Spanish Grand Prix          53
# Canadian Grand Prix         52
# Brazilian Grand Prix        48
# United States Grand Prix    44
# Name: count, dtype: int64

# %%
races_es = races[(races['name'] == 'Spanish Grand Prix') & (races['year'].between(1996, 2022))]
races_es = races_es.drop(['fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time', 'quali_date', 'quali_time', 'sprint_date', 'sprint_time'], axis=1)
races_es = races_es.sort_values(by='raceId', ascending=False)

races_es
# Out:
#       raceId  year  round  circuitId                name        date
# 1062    1079  2022      6          4  Spanish Grand Prix  2022-05-22  \
# 1040    1055  2021      4          4  Spanish Grand Prix  2021-05-09
# 1023    1036  2020      6          4  Spanish Grand Prix  2020-08-16
# 1001    1014  2019      5          4  Spanish Grand Prix  2019-05-12
# 980      993  2018      5          4  Spanish Grand Prix  2018-05-13
# 960      973  2017      5          4  Spanish Grand Prix  2017-05-14
# 939      952  2016      5          4  Spanish Grand Prix  2016-05-15
# 919      930  2015      5          4  Spanish Grand Prix  2015-05-10
# 901      904  2014      5          4  Spanish Grand Prix  2014-05-11
# 882      884  2013      5          4  Spanish Grand Prix  2013-05-12
# 862      864  2012      5          4  Spanish Grand Prix  2012-05-13
# 843      845  2011      5          4  Spanish Grand Prix  2011-05-22
# 340      341  2010      5          4  Spanish Grand Prix  2010-05-09
# ...

# %%
qualifying.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1
# 0          1      18         1              1      22         1  1:26.572  \
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
qualifying_es = qualifying[qualifying['raceId'].isin(races_es['raceId'])]
qualifying_es = qualifying_es.drop(['number', 'q1', 'q2', 'q3'], axis=1)

qualifying_es.head()
# Out:
#     qualifyId  raceId  driverId  constructorId  position
# 66         67      21         8              6         1
# 67         68      21         4              4         2
# 68         69      21        13              6         3
# 69         70      21         9              2         4
# 70         71      21         1              1         5

# %%
qualifying_es = qualifying_es.drop('qualifyId', axis=1)
qualifying_es = qualifying_es.sort_values(by='raceId', ascending=False)

qualifying_es.head()
# Out:
#       raceId  driverId  constructorId  position
# 9254    1079       849              3        20
# 9244    1079       854            210        10
# 9235    1079       844              6         1
# 9236    1079       830              9         2
# 9237    1079       832              6         3

# %%
qualifying_es.shape
# Out:
# (463, 4)

# %%
lap_times.head()
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342

# %%
lap_times_es = lap_times[lap_times['raceId'].isin(races_es['raceId'])]
lap_times_es = lap_times_es.sort_values(by='raceId', ascending=False)
lap_times_es = lap_times_es.drop(['position', 'time', 'milliseconds'], axis=1)

lap_times_es.head()
# Out:
#         raceId  driverId  lap
# 520988    1079       825   64
# 520171    1079       822   57
# 520164    1079       822   50
# 520165    1079       822   51
# 520166    1079       822   52

# %%
lap_times_es['driverId'].value_counts()
# Out:
# driverId
# 4      1150
# 18     1032
# 1       985
# 13      972
# 20      921
#        ...
# 47       17
# 811      12
# 40       11
# 36       10
# 7         4
# Name: count, Length: 117, dtype: int64

# %%
qualifying_es['driverId'].value_counts()
# Out:
# driverId
# 4      18
# 8      17
# 1      16
# 20     15
# 13     14
#        ..
# 83      1
# 845     1
# 73      1
# 843     1
# 823     1
# Name: count, Length: 109, dtype: int64

# %%
len(lap_times_es['raceId'].unique()) == len(races_es['raceId'].unique())
# Out:
# True

# %%
quali_lap_es = qualifying_es.merge(lap_times_es, on=['raceId', 'driverId'], how='left')

quali_lap_es
# Out:
#        raceId  driverId  constructorId  position   lap
# 0        1079       849              3        20   1.0
# 1        1079       849              3        20   2.0
# 2        1079       849              3        20   3.0
# 3        1079       849              3        20   4.0
# 4        1079       849              3        20  23.0
# ...       ...       ...            ...       ...   ...
# 25463       5         3              3         9  58.0
# 25464       5         3              3         9  59.0
# 25465       5         3              3         9  60.0
# 25466       5         3              3         9  61.0
# 25467       5         3              3         9  62.0
#
# [25468 rows x 5 columns]

# %%
quali_lap_es.isna().sum()
# Out:
# raceId            0
# driverId          0
# constructorId     0
# position          0
# lap              20
# dtype: int64

# %%
len(quali_lap_es['raceId'].unique())
# Out:
# 22

# %%
len(quali_lap_es['driverId'].unique())
# Out:
# 109

# %%
null_lap_rows = quali_lap_es[quali_lap_es['lap'].isnull()]

null_lap_rows.head()
# Out:
#       raceId  driverId  constructorId  position  lap
# 5574     993       154            210        10  NaN
# 5620     993       842              5        12  NaN
# 5749     993       807              4        16  NaN
# 6301     973         8              6         4  NaN
# 7461     952         3            131         2  NaN

# %%
quali_lap_es = quali_lap_es.dropna(subset=['lap'])

quali_lap_es
# Out:
#        raceId  driverId  constructorId  position   lap
# 0        1079       849              3        20   1.0
# 1        1079       849              3        20   2.0
# 2        1079       849              3        20   3.0
# 3        1079       849              3        20   4.0
# 4        1079       849              3        20  23.0
# ...       ...       ...            ...       ...   ...
# 25463       5         3              3         9  58.0
# 25464       5         3              3         9  59.0
# 25465       5         3              3         9  60.0
# 25466       5         3              3         9  61.0
# 25467       5         3              3         9  62.0
#
# [25448 rows x 5 columns]

# %%
drivers.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07  \
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
drivers_es = drivers[drivers['driverId'].isin(lap_times_es['driverId'])]
drivers_es = drivers_es.sort_values(by='driverId', ascending=False)

drivers_es
# Out:
#      driverId        driverRef number code  forename     surname         dob
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30  \
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 851       853          mazepin      9  MAZ    Nikita     Mazepin  1999-03-02
# 850       852          tsunoda     22  TSU      Yuki     Tsunoda  2000-05-11
# 847       849           latifi      6  LAT  Nicholas      Latifi  1995-06-29
# ..        ...              ...    ...  ...       ...         ...         ...
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
#
# ...

# %%
race2022 = lap_times[lap_times['raceId'] == 1079]

race2022.shape
# Out:
# (1230, 6)

# %%
race2022.head()
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 519759    1079       844    1         1  1:28.746         88746
# 519760    1079       844    2         1  1:27.627         87627
# 519761    1079       844    3         1  1:27.198         87198
# 519762    1079       844    4         1  1:27.671         87671
# 519763    1079       844    5         1  1:27.891         87891

# %%
race2022['lap'].value_counts()
# Out:
# lap
# 1     20
# 15    20
# 2     20
# 27    20
# 26    20
#       ..
# 42    18
# 43    18
# 44    18
# 65    15
# 66     8
# Name: count, Length: 66, dtype: int64

# %%
race2022_ham = race2022[race2022['driverId'] == 1]

race2022_ham
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 520859    1079         1    1        19  1:55.147        115147
# 520860    1079         1    2        19  1:55.134        115134
# 520861    1079         1    3        19  1:27.495         87495
# 520862    1079         1    4        19  1:28.327         88327
# 520863    1079         1    5        19  1:29.321         89321
# ...        ...       ...  ...       ...       ...           ...
# 520920    1079         1   62         4  1:26.804         86804
# 520921    1079         1   63         4  1:28.977         88977
# 520922    1079         1   64         4  1:29.833         89833
# 520923    1079         1   65         5  1:31.646         91646
# 520924    1079         1   66         5  1:34.345         94345
#
# [66 rows x 6 columns]

# %%
race2021 = lap_times[lap_times['raceId'] == 1055]

race2021.shape
# Out:
# (1246, 6)

# %%
race2021['lap'].value_counts()
# Out:
# lap
# 1     20
# 3     20
# 4     20
# 5     20
# 6     20
#       ..
# 30    19
# 31    19
# 32    19
# 65    17
# 66     7
# Name: count, Length: 66, dtype: int64

# %%
race2020 = lap_times[lap_times['raceId'] == 1055]

race2020.shape
# Out:
# (1246, 6)

# %%
constructors.head()
# Out:
#    constructorId constructorRef        name nationality
# 0              1        mclaren     McLaren     British  \
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
results.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position
# 0         1      18         1              1     22     1        1  \
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds
# 0            1              1    10.0    58  1:34:50.616      5690616  \
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
results_es = results[results['raceId'].isin(races_es['raceId'])]
results_es = results_es.sort_values(by='raceId', ascending=False)

results_es
# Out:
#        resultId  raceId  driverId  constructorId number  grid position
# 25519     25525    1079       844              6     16     1       \N  \
# 25509     25515    1079       852            213     22    13       10
# 25500     25506    1079       830              9      1     2        1
# 25502     25508    1079       847            131     63     4        3
# 25503     25509    1079       832              6     55     3        4
# ...         ...     ...       ...            ...    ...   ...      ...
# 7637       7638       5         4              4      7     8        5
# 7636       7637       5        20              9     15     2        4
# 7635       7636       5        17              9     14     5        3
# 7634       7635       5        22             23     23     3        2
# 7643       7644       5         9              2      5    10       11
#
#       positionText  positionOrder  points  laps         time milliseconds
# ...

# %%
constructors_es = constructors[constructors['constructorId'].isin(results_es['constructorId'])]
constructors_es = constructors_es.sort_values(by='constructorId', ascending=False)

constructors_es.head()
# Out:
#      constructorId constructorRef            name nationality
# 210            214         alpine  Alpine F1 Team      French  \
# 209            213     alphatauri      AlphaTauri     Italian
# 208            211   racing_point    Racing Point     British
# 207            210           haas    Haas F1 Team    American
# 206            209          manor  Manor Marussia     British
#
#                                                    url
# 210        http://en.wikipedia.org/wiki/Alpine_F1_Team
# 209   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 208  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 207          http://en.wikipedia.org/wiki/Haas_F1_Team
# 206      http://en.wikipedia.org/wiki/Manor_Motorsport

# %%
circuit_es = circuit_es.drop('url', axis=1)

circuit_es#.head()
# Out:
#    circuitId circuitRef                            name  location country
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
#
#      lat      lng  alt
# 3  41.57  2.26111  109

# %%
circuit_es.shape
# Out:
# (1, 8)

# %%
constructors_es = constructors_es.drop('url', axis=1)

constructors_es#.head()
# Out:
#      constructorId constructorRef            name nationality
# 210            214         alpine  Alpine F1 Team      French
# 209            213     alphatauri      AlphaTauri     Italian
# 208            211   racing_point    Racing Point     British
# 207            210           haas    Haas F1 Team    American
# 206            209          manor  Manor Marussia     British
# 205            208       lotus_f1        Lotus F1     British
# 204            207       caterham        Caterham   Malaysian
# 203            206       marussia        Marussia     Russian
# 202            205   lotus_racing           Lotus   Malaysian
# 164            166         virgin          Virgin     British
# 162            164            hrt             HRT     Spanish
# 129            131       mercedes        Mercedes      German
# 115            117   aston_martin    Aston Martin     British
# 49              51           alfa      Alfa Romeo       Swiss
# ...

# %%
constructors_es.shape
# Out:
# (41, 4)

# %%
drivers_es['number'].unique()
drivers_es['code'].unique()
# Out:
# array(['ZHO', 'MSC', 'MAZ', 'TSU', 'LAT', 'ALB', 'RUS', 'NOR', 'SIR',
#        'LEC', 'HAR', 'GAS', 'GIO', 'STR', 'OCO', 'VAN', 'WEH', 'PAL',
#        'MER', 'SAI', 'NAS', 'VER', 'STE', 'ERI', 'KVY', 'MAG', 'BIA',
#        'VDG', 'BOT', 'GUT', 'CHI', 'PIC', 'RIC', 'DAM', 'PER', 'DIR',
#        'MAL', 'CHA', 'SEN', 'DIG', 'PET', 'HUL', 'KOB', 'GRO', 'ALG',
#        '\\N', 'BAD', 'BUE', 'ZON', 'FRI', 'KAR', 'DLR', 'FMO', 'VIL',
#        'TMO', 'KLI', 'MON', 'SPE', 'WUR', 'LIU', 'SCH', 'BAR', 'FIS',
#        'VET', 'DAV', 'BUT', 'WEB', 'SUT', 'TRU', 'COU', 'MAS', 'PIQ',
#        'SAT', 'GLO', 'KUB', 'RAI', 'BOU', 'NAK', 'KOV', 'ALO', 'ROS',
#        'HEI', 'HAM'], dtype=object)

# %%
#pd.set_option('display.max_rows', 75)

result = drivers_es.loc[(drivers_es['number'] == r'\N') | (drivers_es['code'] == r'\N')]

result.head()
# Out:
#      driverId driverRef number code forename        surname         dob
# 822       823     garde     \N  VDG    Giedo  van der Garde  1985-04-25  \
# 818       819       pic     \N  PIC  Charles            Pic  1990-02-15
# 815       816  ambrosio     \N  DAM   Jérôme     d'Ambrosio  1985-12-27
# 813       814     resta     \N  DIR     Paul       di Resta  1986-04-16
# 811       812  chandhok     \N  CHA    Karun       Chandhok  1984-01-19
#
#     nationality                                                url
# 822       Dutch   http://en.wikipedia.org/wiki/Giedo_van_der_Garde
# 818      French           http://en.wikipedia.org/wiki/Charles_Pic
# 815     Belgian  http://en.wikipedia.org/wiki/J%C3%A9r%C3%B4me_...
# 813     British         http://en.wikipedia.org/wiki/Paul_di_Resta
# 811      Indian        http://en.wikipedia.org/wiki/Karun_Chandhok

# %%
drivers_es = drivers_es.drop(['number', 'code', 'url'], axis=1)

drivers_es#.head()
# Out:
#      driverId        driverRef  forename     surname         dob nationality
# 853       855             zhou    Guanyu        Zhou  1999-05-30     Chinese
# 852       854  mick_schumacher      Mick  Schumacher  1999-03-22      German
# 851       853          mazepin    Nikita     Mazepin  1999-03-02     Russian
# 850       852          tsunoda      Yuki     Tsunoda  2000-05-11    Japanese
# 847       849           latifi  Nicholas      Latifi  1995-06-29    Canadian
# ..        ...              ...       ...         ...         ...         ...
# 4           5       kovalainen    Heikki  Kovalainen  1981-10-19     Finnish
# 3           4           alonso  Fernando      Alonso  1981-07-29     Spanish
# 2           3          rosberg      Nico     Rosberg  1985-06-27      German
# 1           2         heidfeld      Nick    Heidfeld  1977-05-10      German
# 0           1         hamilton     Lewis    Hamilton  1985-01-07     British
#
# [117 rows x 6 columns]

# %%
pd.set_option('display.max_rows', None)

drivers_es[['driverRef', 'forename', 'surname']]
# Out:
#               driverRef      forename        surname
# 853                zhou        Guanyu           Zhou
# 852     mick_schumacher          Mick     Schumacher
# 851             mazepin        Nikita        Mazepin
# 850             tsunoda          Yuki        Tsunoda
# 847              latifi      Nicholas         Latifi
# 846               albon     Alexander          Albon
# 845             russell        George        Russell
# 844              norris         Lando         Norris
# 843            sirotkin        Sergey       Sirotkin
# 842             leclerc       Charles        Leclerc
# 841     brendon_hartley       Brendon        Hartley
# 452               gasly        Pierre          Gasly
# 840          giovinazzi       Antonio     Giovinazzi
# 839              stroll         Lance         Stroll
# 838                ocon       Esteban           Ocon
# 837           vandoorne       Stoffel      Vandoorne
# 836            haryanto           Rio       Haryanto
# ...

# %%
drivers_es.shape
# Out:
# (117, 6)

# %%
races_es.head()
# Out:
#       raceId  year  round  circuitId                name        date
# 1062    1079  2022      6          4  Spanish Grand Prix  2022-05-22  \
# 1040    1055  2021      4          4  Spanish Grand Prix  2021-05-09
# 1023    1036  2020      6          4  Spanish Grand Prix  2020-08-16
# 1001    1014  2019      5          4  Spanish Grand Prix  2019-05-12
# 980      993  2018      5          4  Spanish Grand Prix  2018-05-13
#
#           time                                                url
# 1062  13:00:00  http://en.wikipedia.org/wiki/2022_Spanish_Gran...
# 1040  13:00:00  http://en.wikipedia.org/wiki/2021_Spanish_Gran...
# 1023  13:10:00  http://en.wikipedia.org/wiki/2020_Spanish_Gran...
# 1001  13:10:00  http://en.wikipedia.org/wiki/2019_Spanish_Gran...
# 980   13:10:00  http://en.wikipedia.org/wiki/2018_Spanish_Gran...

# %%
races_es['time'] = races_es['time'].replace('\\N', '14:00:00')
races_es = races_es.drop('url', axis=1)

# %%
races_es#.head()
# Out:
#       raceId  year  round  circuitId                name        date      time
# 1062    1079  2022      6          4  Spanish Grand Prix  2022-05-22  13:00:00
# 1040    1055  2021      4          4  Spanish Grand Prix  2021-05-09  13:00:00
# 1023    1036  2020      6          4  Spanish Grand Prix  2020-08-16  13:10:00
# 1001    1014  2019      5          4  Spanish Grand Prix  2019-05-12  13:10:00
# 980      993  2018      5          4  Spanish Grand Prix  2018-05-13  13:10:00
# 960      973  2017      5          4  Spanish Grand Prix  2017-05-14  12:00:00
# 939      952  2016      5          4  Spanish Grand Prix  2016-05-15  12:00:00
# 919      930  2015      5          4  Spanish Grand Prix  2015-05-10  12:00:00
# 901      904  2014      5          4  Spanish Grand Prix  2014-05-11  12:00:00
# 882      884  2013      5          4  Spanish Grand Prix  2013-05-12  12:00:00
# 862      864  2012      5          4  Spanish Grand Prix  2012-05-13  12:00:00
# ...

# %%
races_es.shape
# Out:
# (27, 7)

# %%
quali_lap_es = quali_lap_es

quali_lap_es#.head()
# Out:
#        raceId  driverId  constructorId  position   lap
# 0        1079       849              3        20   1.0
# 1        1079       849              3        20   2.0
# 2        1079       849              3        20   3.0
# 3        1079       849              3        20   4.0
# 4        1079       849              3        20  23.0
# ...       ...       ...            ...       ...   ...
# 25463       5         3              3         9  58.0
# 25464       5         3              3         9  59.0
# 25465       5         3              3         9  60.0
# 25466       5         3              3         9  61.0
# 25467       5         3              3         9  62.0
#
# [25448 rows x 5 columns]

# %%
quali_lap_es.shape
# Out:
# (25448, 5)

# %%
result = quali_lap_es.loc[(quali_lap_es['position'] == r'\N') | (lap_times_es['lap'] == r'\N')]

result
# Out:
# Empty DataFrame
# Columns: [raceId, driverId, constructorId, position, lap]
# Index: []

# %%
circuit_es
# Out:
#    circuitId circuitRef                            name  location country
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
#
#      lat      lng  alt
# 3  41.57  2.26111  109

# %%
races_es.head()
# Out:
#       raceId  year  round  circuitId                name        date      time
# 1062    1079  2022      6          4  Spanish Grand Prix  2022-05-22  13:00:00
# 1040    1055  2021      4          4  Spanish Grand Prix  2021-05-09  13:00:00
# 1023    1036  2020      6          4  Spanish Grand Prix  2020-08-16  13:10:00
# 1001    1014  2019      5          4  Spanish Grand Prix  2019-05-12  13:10:00
# 980      993  2018      5          4  Spanish Grand Prix  2018-05-13  13:10:00

# %%
races_es.shape
# Out:
# (27, 7)

# %%
race_circ_es = circuit_es.merge(races_es, on='circuitId', how='left')

race_circ_es.head()
# Out:
#    circuitId circuitRef                          name_x  location country
# 0          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
# 1          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 2          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 4          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
#
#      lat      lng  alt  raceId  year  round              name_y        date
# 0  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22  \
# 1  41.57  2.26111  109    1055  2021      4  Spanish Grand Prix  2021-05-09
# 2  41.57  2.26111  109    1036  2020      6  Spanish Grand Prix  2020-08-16
# 3  41.57  2.26111  109    1014  2019      5  Spanish Grand Prix  2019-05-12
# 4  41.57  2.26111  109     993  2018      5  Spanish Grand Prix  2018-05-13
#
#        time
# 0  13:00:00
# 1  13:00:00
# 2  13:10:00
# ...

# %%
quali_lap_es#.head()
# Out:
#        raceId  driverId  constructorId  position   lap
# 0        1079       849              3        20   1.0
# 1        1079       849              3        20   2.0
# 2        1079       849              3        20   3.0
# 3        1079       849              3        20   4.0
# 4        1079       849              3        20  23.0
# ...       ...       ...            ...       ...   ...
# 25463       5         3              3         9  58.0
# 25464       5         3              3         9  59.0
# 25465       5         3              3         9  60.0
# 25466       5         3              3         9  61.0
# 25467       5         3              3         9  62.0
#
# [25448 rows x 5 columns]

# %%
race_circ_lap_es = race_circ_es.merge(quali_lap_es, on='raceId', how='left')

race_circ_lap_es.head()
# Out:
#    circuitId circuitRef                          name_x  location country
# 0          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
# 1          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 2          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 4          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
#
#      lat      lng  alt  raceId  year  round              name_y        date
# 0  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22  \
# 1  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 2  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 3  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 4  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
#
#        time  driverId  constructorId  position   lap
# ...

# %%
race_circ_lap_es.shape
# Out:
# (25453, 18)

# %%
drivers_es.head()
# Out:
#      driverId        driverRef  forename     surname         dob nationality
# 853       855             zhou    Guanyu        Zhou  1999-05-30     Chinese
# 852       854  mick_schumacher      Mick  Schumacher  1999-03-22      German
# 851       853          mazepin    Nikita     Mazepin  1999-03-02     Russian
# 850       852          tsunoda      Yuki     Tsunoda  2000-05-11    Japanese
# 847       849           latifi  Nicholas      Latifi  1995-06-29    Canadian

# %%
drivers_es.shape
# Out:
# (117, 6)

# %%
race_circ_lap_driv_es = race_circ_lap_es.merge(drivers_es, on='driverId', how='left')

race_circ_lap_driv_es.head()
# Out:
#    circuitId circuitRef                          name_x  location country
# 0          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
# 1          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 2          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 4          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
#
#      lat      lng  alt  raceId  year  round              name_y        date
# 0  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22  \
# 1  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 2  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 3  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 4  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
#
# ...

# %%
constructors_es.head()
# Out:
#      constructorId constructorRef            name nationality
# 210            214         alpine  Alpine F1 Team      French
# 209            213     alphatauri      AlphaTauri     Italian
# 208            211   racing_point    Racing Point     British
# 207            210           haas    Haas F1 Team    American
# 206            209          manor  Manor Marussia     British

# %%
constructors_es.shape
# Out:
# (41, 4)

# %%
pd.set_option('display.max_columns', 30)

race_circ_lap_driv_cons_es = race_circ_lap_driv_es.merge(constructors_es, on='constructorId', how='left')

race_circ_lap_driv_cons_es.head()
# Out:
#    circuitId circuitRef                          name_x  location country
# 0          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
# 1          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 2          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 4          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
#
#      lat      lng  alt  raceId  year  round              name_y        date
# 0  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22  \
# 1  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 2  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 3  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 4  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
#
# ...

# %%
race_circ_lap_driv_cons_es.shape
# Out:
# (25453, 26)

# %%
race_circ_lap_driv_cons_es.columns
# Out:
# Index(['circuitId', 'circuitRef', 'name_x', 'location', 'country', 'lat',
#        'lng', 'alt', 'raceId', 'year', 'round', 'name_y', 'date', 'time',
#        'driverId', 'constructorId', 'position', 'lap', 'driverRef', 'forename',
#        'surname', 'dob', 'nationality_x', 'constructorRef', 'name',
#        'nationality_y'],
#       dtype='object')

# %%
race_circ_lap_driv_cons_es = race_circ_lap_driv_cons_es.rename(columns={
'name_x': 'name',
'name_y': 'grand_prix',
'nationality_x': 'driver_nationality',
'nationality_y': 'const_nationality'
})

race_circ_lap_driv_cons_es.head()
# Out:
#    circuitId circuitRef                            name  location country
# 0          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
# 1          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 2          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 4          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
#
#      lat      lng  alt  raceId  year  round          grand_prix        date
# 0  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22  \
# 1  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 2  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 3  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 4  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
#
# ...

# %%
safety = safety[safety['Grand Prix'] == 'Spanish Grand Prix']

safety = safety.rename(columns={
'Grand Prix': 'grand_prix',
'Cause': 'cause',
'Deployed (lap)': 'deployed_lap',
'Called in (lap)': 'called_in_lap',
'Number of full laps': 'number_full_laps',
'Year': 'year'
})

safety.head()
# Out:
#              grand_prix         cause deployed_lap called_in_lap
# 13   Spanish Grand Prix  Stranded car            8            10  \
# 46   Spanish Grand Prix      Accident           46            52
# 64   Spanish Grand Prix      Accident            1             6
# 189  Spanish Grand Prix      Accident            1             5
# 204  Spanish Grand Prix      Accident            1             4
#
#      number_full_laps  year
# 13                  1  2021
# 46                  5  2019
# 64                  4  2018
# 189                 3  2009
# 204                 2  2008

# %%
race_circ_lap_driv_cons_es['safety_car'] = ((race_circ_lap_driv_cons_es['year'] == 2021) & (race_circ_lap_driv_cons_es['lap'].isin([8, 9, 10]))) | ((race_circ_lap_driv_cons_es['year'] == 2019) & (race_circ_lap_driv_cons_es['lap'].isin([46, 47, 48, 49, 50, 51, 52])) | (race_circ_lap_driv_cons_es['year'] == 2018) & (race_circ_lap_driv_cons_es['lap'].isin([1, 2, 3, 4, 5, 6])) | (race_circ_lap_driv_cons_es['year'] == 2009) & (race_circ_lap_driv_cons_es['lap'].isin([1, 2, 3, 4, 5])) | (race_circ_lap_driv_cons_es['year'] == 2008) & (race_circ_lap_driv_cons_es['lap'].isin([1, 2, 3, 4])))

race_circ_lap_driv_cons_es.head()
# Out:
#    circuitId circuitRef                            name  location country
# 0          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain  \
# 1          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 2          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 3          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
# 4          4  catalunya  Circuit de Barcelona-Catalunya  Montmeló   Spain
#
#      lat      lng  alt  raceId  year  round          grand_prix        date
# 0  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22  \
# 1  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 2  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 3  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
# 4  41.57  2.26111  109    1079  2022      6  Spanish Grand Prix  2022-05-22
#
# ...

# %%
race_circ_lap_driv_cons_es['safety_car'].value_counts()
# Out:
# safety_car
# False    25008
# True       445
# Name: count, dtype: int64

# %%
d_points = d_points.drop(['Nationality', 'Year'], axis=1)

d_points = d_points.rename(columns={
'Driver': 'driver',
'Team': 'team',
'Points': 'driver_points'
})

d_points.head()

# %%
c_points = c_points.drop('Year', axis=1)

c_points = c_points.rename(columns={
'Team': 'team',
'Points': 'const_points'
})

c_points.head()
